# %% [markdown]
# ### Libray Import
#
# 필요한 라이브러리를 import 합니다.

# %%
import cv2
import os
os.environ['CUDA_LAUNCH_BLOCKING'] = "1"
import numpy as np
import torch
import torch.fft as fft
import random
import timm
import torchvision.transforms as transforms
from torch.utils.data import Dataset
import torch.nn as nn
import torch.optim as optim
from torch.utils.data import DataLoader, random_split
from torchvision import models, transforms
from tqdm import tqdm
from torch.optim.lr_scheduler import CosineAnnealingLR

def set_seed(seed=None):
    """모든 랜덤 시드를 고정하는 함수."""
    random.seed(seed)  # Python 내장 랜덤 모듈
    np.random.seed(seed)  # NumPy
    torch.manual_seed(seed)  # CPU를 위한 PyTorch 시드
    torch.cuda.manual_seed(seed)  # GPU를 위한 PyTorch 시드
    torch.cuda.manual_seed_all(seed)  # 멀티 GPU를 위한 PyTorch 시드
    os.environ['PYTHONHASHSEED'] = str(seed)  # Python 해시 기반 작업을 위한 시드

    # PyTorch의 일관된 작업을 위해 다음 설정을 고려할 수 있습니다
    torch.backends.cudnn.deterministic = True
    torch.backends.cudnn.benchmark = False

# %%
set_seed(42)
if torch.cuda.is_available():
    print("GPU is available.")
    device = torch.device("cuda")
else:
    print("GPU is not available. Using CPU instead.")
    device = torch.device("cpu")
# Out:
# GPU is available.

# %%
def extract_frames(video_path, frame_count=1, resize=(224, 224)):
    cap = cv2.VideoCapture(video_path)
    total_frames = int(cap.get(cv2.CAP_PROP_FRAME_COUNT))
    frames = []
    
    step = max(1, np.floor(total_frames / frame_count).astype(int))

    for i in range(frame_count):
        cap.set(cv2.CAP_PROP_POS_FRAMES, i * step)
        ret, frame = cap.read()
        if not ret:
            break
        frame = cv2.cvtColor(frame, cv2.COLOR_BGR2RGB)  # OpenCV uses BGR by default
        frames.append(frame)

    cap.release()
    return frames

# %%
class VideoDataset(Dataset):
    def __init__(self, directory, frame_count=1, resize=(224, 224), transform=None, mode='train'):
        self.directory = directory
        self.frame_count = frame_count
        self.resize = resize
        self.transform = transform
        self.mode = mode
        self.classes = ['real', 'fake']
        self.videos = []

        if mode in ['train', 'val']:
            for label in self.classes:
                class_dir = os.path.join(directory, label)
                for video in os.listdir(class_dir):
                    self.videos.append((os.path.join(class_dir, video), label))
        elif mode == 'test':
            for video in directory:
                #                 print(video)
                self.videos.append((video, None))

    def __len__(self):
        return len(self.videos)

    def __getitem__(self, idx):
        video_path, label = self.videos[idx]
        video_name = os.path.basename(video_path)  # 비디오 파일 이름 추출
        frames = extract_frames(video_path, self.frame_count, self.resize)

        if self.transform:
            frames = [self.transform(frame) for frame in frames]
            fft_frames = [torch.abs(fft.fft2(frame, dim=(1, 2), norm='ortho')) for frame in frames]

        frames = np.stack(frames)
        frames = torch.from_numpy(frames).float()
        frames = frames.squeeze()

        fft_frames = np.stack(fft_frames)
        fft_frames = torch.from_numpy(fft_frames).float()
        fft_frames = fft_frames.squeeze()

        if self.mode in ['train', 'val']:
            label = torch.tensor(self.classes.index(label))
        elif self.mode == 'test':
            return frames, fft_frames  

        return frames, fft_frames, label

# %% [markdown]
# ### 모델링
#
# 학습데이터를 이용하여 자유롭게 모델링 해보세요!

# %%
## model for fft domain.
class VideoClassifier(nn.Module):
    def __init__(self, num_classes=1):
        super(VideoClassifier, self).__init__()
        self.img_model = timm.create_model('xception', pretrained=True)
        self.fft_model = timm.create_model('swinv2_small_window8_256.ms_in1k', pretrained=True)
        in_ch_img = self.img_model.fc.in_features
        in_ch_fft = self.fft_model.head.in_features
        self.img_model.fc = nn.Identity()
        self.fft_model.head.fc = nn.Identity()
        
        self.out = nn.Linear(in_ch_img + in_ch_fft, 2)

    def forward(self, img, fft):
        img_f = self.img_model(img)
        fft_f = self.fft_model(fft)
        x = torch.cat((fft_f, img_f), dim=1)
        return self.out(x)

# %%
TRAIN_PATH = '/mnt/elice/dataset/train'
TEST_PATH = '/mnt/elice/dataset/test'

# %%
transform = transforms.Compose([
    transforms.ToTensor(),
    transforms.CenterCrop(256),
    transforms.Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225])
])

# %%
# 데이터셋 및 데이터 로더 설정
dataset = VideoDataset(directory=TRAIN_PATH, transform=transform)
total_size = len(dataset)
train_size = int(total_size * 0.7)
val_size = total_size - train_size

train_dataset, val_dataset = random_split(dataset, [train_size, val_size])

train_loader = DataLoader(train_dataset, batch_size=32, shuffle=True)
val_loader = DataLoader(val_dataset, batch_size=32, shuffle=False)


print(total_size,train_size,val_size )

# %% [markdown]
# ## model #1

# %%
model_resnet50 = timm.create_model('res2net50_26w_4s', pretrained=True, num_classes=2).to(device)
criterion = nn.CrossEntropyLoss()
optimizer = optim.Adam(model_resnet50.parameters(), lr=0.0001)

num_epochs = 10
scheduler = CosineAnnealingLR(optimizer, T_max=num_epochs)
best_val_loss = float('inf')

# %%
for epoch in range(num_epochs):
    model_resnet50.train()
    train_loss = 0.0
    train_correct = 0
    train_total = 0

    for data in tqdm(train_loader, desc=f"Epoch {epoch+1}/{num_epochs} [Train]"):
        inputs, _, labels = data
        inputs, labels = inputs.to(device), labels.to(device)

        optimizer.zero_grad()
        outputs = model_resnet50(inputs)
        loss = criterion(outputs, labels)
        loss.backward()
        optimizer.step()

        train_loss += loss.item()
        _, predicted = torch.max(outputs.data, 1)
        train_total += labels.size(0)
        train_correct += (predicted == labels).sum().item()

    train_accuracy = 100 * train_correct / train_total
    train_loss /= train_total

    model_resnet50.eval()
    val_loss = 0.0
    val_correct = 0
    val_total = 0
    with torch.no_grad():
        for data in tqdm(val_loader, desc=f"Epoch {epoch+1}/{num_epochs} [Validation]"):
            inputs, _, labels = data
            inputs, labels = inputs.to(device), labels.to(device)
            outputs = model_resnet50(inputs)

            loss = criterion(outputs, labels)
            val_loss += loss.item()
            _, predicted = torch.max(outputs.data, 1)
            val_total += labels.size(0)
            val_correct += (predicted == labels).sum().item()

    val_accuracy = 100 * val_correct / val_total
    val_loss /= val_total

    print(f"Epoch {epoch+1}/{num_epochs}, Train Loss: {train_loss:.4f}, Train Acc: {train_accuracy:.2f}%, Val Loss: {val_loss:.4f}, Val Acc: {val_accuracy:.2f}%")
    # 에포크가 끝날 때마다 스케줄러 업데이트
    scheduler.step()

    # 현재 학습률 출력
    current_lr = scheduler.get_last_lr()[0]
    print(f"Current Learning Rate: {current_lr:.6f}")

    # 검증 손실이 이전의 최고값보다 낮으면 모델 저장
    if val_loss < best_val_loss:
        best_val_loss = val_loss
        torch.save(model_resnet50.state_dict(), 'resnet_best_model_0.9726.pt')

# %% [markdown]
# ## model #2

# %%
model_inc4 = timm.models.inception_v4(pretrained=True,num_classes=2).to(device)
criterion = nn.CrossEntropyLoss()
optimizer = optim.Adam(model_inc4.parameters(), lr=0.0001)

num_epochs = 10
scheduler = CosineAnnealingLR(optimizer, T_max=num_epochs)
best_val_loss = float('inf')

# %%
for epoch in range(num_epochs):
    model_inc4.train()
    train_loss = 0.0
    train_correct = 0
    train_total = 0

    for data in tqdm(train_loader, desc=f"Epoch {epoch+1}/{num_epochs} [Train]"):
        inputs, _, labels = data
        inputs, labels = inputs.to(device), labels.to(device)

        optimizer.zero_grad()
        outputs = model_inc4(inputs)
        loss = criterion(outputs, labels)
        loss.backward()
        optimizer.step()

        train_loss += loss.item()
        _, predicted = torch.max(outputs.data, 1)
        train_total += labels.size(0)
        train_correct += (predicted == labels).sum().item()

    train_accuracy = 100 * train_correct / train_total
    train_loss /= train_total

    model_inc4.eval()
    val_loss = 0.0
    val_correct = 0
    val_total = 0
    with torch.no_grad():
        for data in tqdm(val_loader, desc=f"Epoch {epoch+1}/{num_epochs} [Validation]"):
            inputs, _, labels = data
            inputs, labels = inputs.to(device), labels.to(device)
            outputs = model_inc4(inputs)

            loss = criterion(outputs, labels)
            val_loss += loss.item()
            _, predicted = torch.max(outputs.data, 1)
            val_total += labels.size(0)
            val_correct += (predicted == labels).sum().item()

    val_accuracy = 100 * val_correct / val_total
    val_loss /= val_total

    print(f"Epoch {epoch+1}/{num_epochs}, Train Loss: {train_loss:.4f}, Train Acc: {train_accuracy:.2f}%, Val Loss: {val_loss:.4f}, Val Acc: {val_accuracy:.2f}%")
    # 에포크가 끝날 때마다 스케줄러 업데이트
    scheduler.step()

    # 현재 학습률 출력
    current_lr = scheduler.get_last_lr()[0]
    print(f"Current Learning Rate: {current_lr:.6f}")

    # 검증 손실이 이전의 최고값보다 낮으면 모델 저장
    if val_loss < best_val_loss:
        best_val_loss = val_loss
        torch.save(model_inc4.state_dict(), 'incv4_model_0.974.pt')

# %% [markdown]
# ## model #3

# %%
model_xception = timm.create_model('xception', pretrained=True, num_classes=2).to(device)
criterion = nn.CrossEntropyLoss()
optimizer = optim.Adam(model_xception.parameters(), lr=0.0001)

num_epochs = 10
scheduler = CosineAnnealingLR(optimizer, T_max=num_epochs)
best_val_loss = float('inf')

# %%
for epoch in range(num_epochs):
    model_xception.train()
    train_loss = 0.0
    train_correct = 0
    train_total = 0

    for data in tqdm(train_loader, desc=f"Epoch {epoch+1}/{num_epochs} [Train]"):
        inputs, _, labels = data
        inputs, labels = inputs.to(device), labels.to(device)

        optimizer.zero_grad()
        outputs = model_xception(inputs)
        loss = criterion(outputs, labels)
        loss.backward()
        optimizer.step()

        train_loss += loss.item()
        _, predicted = torch.max(outputs.data, 1)
        train_total += labels.size(0)
        train_correct += (predicted == labels).sum().item()

    train_accuracy = 100 * train_correct / train_total
    train_loss /= train_total

    model_xception.eval()
    val_loss = 0.0
    val_correct = 0
    val_total = 0
    with torch.no_grad():
        for data in tqdm(val_loader, desc=f"Epoch {epoch+1}/{num_epochs} [Validation]"):
            inputs, _, labels = data
            inputs, labels = inputs.to(device), labels.to(device)
            outputs = model_xception(inputs)

            loss = criterion(outputs, labels)
            val_loss += loss.item()
            _, predicted = torch.max(outputs.data, 1)
            val_total += labels.size(0)
            val_correct += (predicted == labels).sum().item()

    val_accuracy = 100 * val_correct / val_total
    val_loss /= val_total

    print(f"Epoch {epoch+1}/{num_epochs}, Train Loss: {train_loss:.4f}, Train Acc: {train_accuracy:.2f}%, Val Loss: {val_loss:.4f}, Val Acc: {val_accuracy:.2f}%")
    # 에포크가 끝날 때마다 스케줄러 업데이트
    scheduler.step()

    # 현재 학습률 출력
    current_lr = scheduler.get_last_lr()[0]
    print(f"Current Learning Rate: {current_lr:.6f}")

    # 검증 손실이 이전의 최고값보다 낮으면 모델 저장
    if val_loss < best_val_loss:
        best_val_loss = val_loss
        torch.save(model_xception.state_dict(), 'xception_best_model_0.974.pt')

# %% [markdown]
# ## model #4

# %%
model_resnext50d_32x4d = timm.models.resnext50d_32x4d(pretrained=True,num_classes=2).to(device)
criterion = nn.CrossEntropyLoss()
optimizer = optim.Adam(model_resnext50d_32x4d.parameters(), lr=0.0001)

num_epochs = 10
scheduler = CosineAnnealingLR(optimizer, T_max=num_epochs)
best_val_loss = float('inf')

# %%
for epoch in range(num_epochs):
    model_resnext50d_32x4d.train()
    train_loss = 0.0
    train_correct = 0
    train_total = 0

    for data in tqdm(train_loader, desc=f"Epoch {epoch+1}/{num_epochs} [Train]"):
        inputs, _, labels = data
        inputs, labels = inputs.to(device), labels.to(device)

        optimizer.zero_grad()
        outputs = model_resnext50d_32x4d(inputs)
        loss = criterion(outputs, labels)
        loss.backward()
        optimizer.step()

        train_loss += loss.item()
        _, predicted = torch.max(outputs.data, 1)
        train_total += labels.size(0)
        train_correct += (predicted == labels).sum().item()

    train_accuracy = 100 * train_correct / train_total
    train_loss /= train_total

    model_resnext50d_32x4d.eval()
    val_loss = 0.0
    val_correct = 0
    val_total = 0
    with torch.no_grad():
        for data in tqdm(val_loader, desc=f"Epoch {epoch+1}/{num_epochs} [Validation]"):
            inputs, _, labels = data
            inputs, labels = inputs.to(device), labels.to(device)
            outputs = model_resnext50d_32x4d(inputs)

            loss = criterion(outputs, labels)
            val_loss += loss.item()
            _, predicted = torch.max(outputs.data, 1)
            val_total += labels.size(0)
            val_correct += (predicted == labels).sum().item()

    val_accuracy = 100 * val_correct / val_total
    val_loss /= val_total

    print(f"Epoch {epoch+1}/{num_epochs}, Train Loss: {train_loss:.4f}, Train Acc: {train_accuracy:.2f}%, Val Loss: {val_loss:.4f}, Val Acc: {val_accuracy:.2f}%")
    # 에포크가 끝날 때마다 스케줄러 업데이트
    scheduler.step()

    # 현재 학습률 출력
    current_lr = scheduler.get_last_lr()[0]
    print(f"Current Learning Rate: {current_lr:.6f}")

    # 검증 손실이 이전의 최고값보다 낮으면 모델 저장
    if val_loss < best_val_loss:
        best_val_loss = val_loss
        torch.save(model_resnext50d_32x4d.state_dict(), 'resnext_best_model_0.975.pt')

# %% [markdown]
# ## model #5

# %%
model_renest50d = timm.create_model('resnest50d.in1k', pretrained=True, num_classes=2).to(device)
criterion = nn.CrossEntropyLoss()
optimizer = optim.Adam(model_renest50d.parameters(), lr=0.0001)

num_epochs = 10
scheduler = CosineAnnealingLR(optimizer, T_max=num_epochs)
best_val_loss = float('inf')

# %%
for epoch in range(num_epochs):
    model_renest50d.train()
    train_loss = 0.0
    train_correct = 0
    train_total = 0

    for data in tqdm(train_loader, desc=f"Epoch {epoch+1}/{num_epochs} [Train]"):
        inputs, _, labels = data
        inputs, labels = inputs.to(device), labels.to(device)

        optimizer.zero_grad()
        outputs = model_renest50d(inputs)
        loss = criterion(outputs, labels)
        loss.backward()
        optimizer.step()

        train_loss += loss.item()
        _, predicted = torch.max(outputs.data, 1)
        train_total += labels.size(0)
        train_correct += (predicted == labels).sum().item()

    train_accuracy = 100 * train_correct / train_total
    train_loss /= train_total

    model_renest50d.eval()
    val_loss = 0.0
    val_correct = 0
    val_total = 0
    with torch.no_grad():
        for data in tqdm(val_loader, desc=f"Epoch {epoch+1}/{num_epochs} [Validation]"):
            inputs, _, labels = data
            inputs, labels = inputs.to(device), labels.to(device)
            outputs = model_renest50d(inputs)

            loss = criterion(outputs, labels)
            val_loss += loss.item()
            _, predicted = torch.max(outputs.data, 1)
            val_total += labels.size(0)
            val_correct += (predicted == labels).sum().item()

    val_accuracy = 100 * val_correct / val_total
    val_loss /= val_total

    print(f"Epoch {epoch+1}/{num_epochs}, Train Loss: {train_loss:.4f}, Train Acc: {train_accuracy:.2f}%, Val Loss: {val_loss:.4f}, Val Acc: {val_accuracy:.2f}%")
    # 에포크가 끝날 때마다 스케줄러 업데이트
    scheduler.step()

    # 현재 학습률 출력
    current_lr = scheduler.get_last_lr()[0]
    print(f"Current Learning Rate: {current_lr:.6f}")

    # 검증 손실이 이전의 최고값보다 낮으면 모델 저장
    if val_loss < best_val_loss:
        best_val_loss = val_loss
        torch.save(model_renest50d.state_dict(), 'resnest_best_model_0.976.pt')

# %% [markdown]
# ## model #6

# %%
model_twin = VideoClassifier(num_classes=2).to(device)
criterion = nn.CrossEntropyLoss()
optimizer = optim.Adam(model_twin.parameters(), lr=0.0001)

num_epochs = 10
scheduler = CosineAnnealingLR(optimizer, T_max=num_epochs)
best_val_loss = float('inf')

# %%
for epoch in range(num_epochs):
    model_twin.train()
    train_loss = 0.0
    train_correct = 0
    train_total = 0

    for data in tqdm(train_loader, desc=f"Epoch {epoch+1}/{num_epochs} [Train]"):
        img_inputs, fft_img, labels = data
        img_inputs, fft_img,labels = img_inputs.to(device),fft_img.to(device),  labels.to(device)

        optimizer.zero_grad()
        outputs = model_twin(img_inputs, fft_img)
        loss = criterion(outputs, labels)
        loss.backward()
        optimizer.step()

        train_loss += loss.item()
        _, predicted = torch.max(outputs.data, 1)
        train_total += labels.size(0)
        train_correct += (predicted == labels).sum().item()

    train_accuracy = 100 * train_correct / train_total
    train_loss /= train_total

    model_twin.eval()
    val_loss = 0.0
    val_correct = 0
    val_total = 0
    with torch.no_grad():
        for data in tqdm(val_loader, desc=f"Epoch {epoch+1}/{num_epochs} [Validation]"):
            img_inputs, fft_img, labels = data
            img_inputs, fft_img,labels = img_inputs.to(device),fft_img.to(device),  labels.to(device)
            outputs = model_twin(img_inputs, fft_img)

            loss = criterion(outputs, labels)
            val_loss += loss.item()
            _, predicted = torch.max(outputs.data, 1)
            val_total += labels.size(0)
            val_correct += (predicted == labels).sum().item()

    val_accuracy = 100 * val_correct / val_total
    val_loss /= val_total

    print(f"Epoch {epoch+1}/{num_epochs}, Train Loss: {train_loss:.4f}, Train Acc: {train_accuracy:.2f}%, Val Loss: {val_loss:.4f}, Val Acc: {val_accuracy:.2f}%")
    # 에포크가 끝날 때마다 스케줄러 업데이트
    scheduler.step()

    # 현재 학습률 출력
    current_lr = scheduler.get_last_lr()[0]
    print(f"Current Learning Rate: {current_lr:.6f}")

    # 검증 손실이 이전의 최고값보다 낮으면 모델 저장
    if val_loss < best_val_loss:
        best_val_loss = val_loss
        torch.save(model_twin.state_dict(), 'best_model_twin_0.972.pt')

# %% [markdown]
# ## 추론 시작

# %%
from glob import glob
test_files = sorted(glob(TEST_PATH+'/*'))
test_files
# Out:
# ['/mnt/elice/dataset/test/000ee59f529d4d069edee33b887bb2ce.mp4',
#  '/mnt/elice/dataset/test/0018214f560f4ba3871dd9218f55dd48.mp4',
#  '/mnt/elice/dataset/test/00241f732f934e2b807cf493d02ff80b.mp4',
#  '/mnt/elice/dataset/test/00473872f36940a0bfe3f3dfd7667449.mp4',
#  '/mnt/elice/dataset/test/004d9c5bee68438397889c71a32a05d5.mp4',
#  '/mnt/elice/dataset/test/005dfa81cca84c03a0ecbf6d615af3a1.mp4',
#  '/mnt/elice/dataset/test/005ed57ae7a34ba392f55bcbb3343440.mp4',
#  '/mnt/elice/dataset/test/008a9931aed04545adda460e972547e5.mp4',
#  '/mnt/elice/dataset/test/009fab774fb241d8910323674dedef1c.mp4',
#  '/mnt/elice/dataset/test/00cc2ff2ff78411aa9f4e472589f1f22.mp4',
#  '/mnt/elice/dataset/test/00d061fd346749a985a11eebdd16489c.mp4',
#  '/mnt/elice/dataset/test/00f0a2639d3547fca2b52f45ea153189.mp4',
#  '/mnt/elice/dataset/test/0102a1124d124527a9022c2d8288332f.mp4',
#  '/mnt/elice/dataset/test/0106e97f13b64e6b9fe75a976e5dd4f0.mp4',
#  '/mnt/elice/dataset/test/010fc942573e4679b755acfc1205d91a.mp4',
#  '/mnt/elice/dataset/test/014988abe3df43c1ab087de72f0c319c.mp4',
#  '/mnt/elice/dataset/test/014c9bcb96204c9f92b5aed6137c7e71.mp4',
#  '/mnt/elice/dataset/test/015d6caacfc84d6da1e5297135955cd3.mp4',
#  '/mnt/elice/dataset/test/018be44da78d46618ce53eabb741e00b.mp4',
#  '/mnt/elice/dataset/test/018d19280be54ce1987cec5be3f4e6f8.mp4',
#  '/mnt/elice/dataset/test/01a668ac0d9640bfbefd069f002cc37c.mp4',
#  '/mnt/elice/dataset/test/01ac068bb7784152b4ba7c350b67dd30.mp4',
#  '/mnt/elice/dataset/test/01e049bf03874294aa542e3a5741171d.mp4',
#  '/mnt/elice/dataset/test/01f94ad6e6894040a3a7cb987922ec9b.mp4',
#  '/mnt/elice/dataset/test/020d49ab5d7745afa11a2c5d1eeab1d3.mp4',
#  '/mnt/elice/dataset/test/021deb9f90be4b368fad52c64b23e95d.mp4',
#  '/mnt/elice/dataset/test/0227cbc19fe149df9ba0f7f9ebea895c.mp4',
#  '/mnt/elice/dataset/test/02328c72c67740ad9f604a1c32b2e2ff.mp4',
#  '/mnt/elice/dataset/test/02378ca505a440cfa10032e2fbd8c3f8.mp4',
#  '/mnt/elice/dataset/test/0253d51190024122b610f028c415aa8a.mp4',
#  '/mnt/elice/dataset/test/02588e7bf07b4168a7a773ee34a58e44.mp4',
#  '/mnt/elice/dataset/test/025bbe3ccba944d2a4dcc71f94dd9f75.mp4',
#  '/mnt/elice/dataset/test/027ce3dfd7824685996acd8cd4988c20.mp4',
#  '/mnt/elice/dataset/test/028120b1f6c0407e98d7db909fe3f8ae.mp4',
#  '/mnt/elice/dataset/test/02f33bf835a74aa79e6629419febb57b.mp4',
#  '/mnt/elice/dataset/test/0313cf39dcc244f29f60e05dc2308ef4.mp4',
#  '/mnt/elice/dataset/test/032007ad0ba54099a1171335c14d29b9.mp4',
#  '/mnt/elice/dataset/test/0320b380cf914432a4b3282c49057af9.mp4',
#  '/mnt/elice/dataset/test/0326ee2cf2534a26aa1d0470ac6bfd3f.mp4',
#  '/mnt/elice/dataset/test/032eb588f21245d4a774d3c563309eb6.mp4',
#  '/mnt/elice/dataset/test/034b161391f24deb9cee97bec8da7f66.mp4',
#  '/mnt/elice/dataset/test/03548d7028a846b1af1495a3e1d08a05.mp4',
#  '/mnt/elice/dataset/test/036c8005b4764d1da1c5681bdf0e1761.mp4',
#  '/mnt/elice/dataset/test/038a1492b0a24539b27fb62aa27166f4.mp4',
#  '/mnt/elice/dataset/test/03b6b2b5fa704d609753a63db16e97b6.mp4',
#  '/mnt/elice/dataset/test/03bbec882ee9426ab9b07f78c3ea2081.mp4',
#  '/mnt/elice/dataset/test/03c72e12a1094629a00af129d713d97a.mp4',
#  '/mnt/elice/dataset/test/03dc2478712941b4a7ce2a8ab7c26dac.mp4',
#  '/mnt/elice/dataset/test/03ebf24c95db4994a221244c3237fa6b.mp4',
#  '/mnt/elice/dataset/test/042506bc46a14b3eb6b48308f8a53e21.mp4',
#  '/mnt/elice/dataset/test/042af08a17ba46c180d536693a9d7574.mp4',
#  '/mnt/elice/dataset/test/0433369d9ee74a459cf19cad4e2e8913.mp4',
#  '/mnt/elice/dataset/test/0480ca703e8a441b84f4dbd9d38484b0.mp4',
#  '/mnt/elice/dataset/test/04bf9c5050cc483f856efa00a949f47e.mp4',
#  '/mnt/elice/dataset/test/04c02a276afd4db4935df8c44949b26d.mp4',
#  '/mnt/elice/dataset/test/04c808e710bb49fab3963dfb502bd24e.mp4',
#  '/mnt/elice/dataset/test/04d547972f2f484b93f8695ac13b77f7.mp4',
#  '/mnt/elice/dataset/test/04d5ad280cf44fc3bea106614145efa5.mp4',
#  '/mnt/elice/dataset/test/050717acba3e450593438773e2e35ce7.mp4',
#  '/mnt/elice/dataset/test/0510f0d399844d57beb6f8ea7526c272.mp4',
#  '/mnt/elice/dataset/test/05181b070976446d841f2a934d3e7351.mp4',
#  '/mnt/elice/dataset/test/0520be983a6042f3838da798ea395276.mp4',
#  '/mnt/elice/dataset/test/05280f590ed24821b6888ff8e2ba7632.mp4',
#  '/mnt/elice/dataset/test/052d72f2e2954f01afd9f7a6bada29a1.mp4',
#  '/mnt/elice/dataset/test/052fa3acdc0a4c3dbb0c8c9931e29755.mp4',
#  '/mnt/elice/dataset/test/0533fef7d474435983a19084cdf2d0e0.mp4',
#  '/mnt/elice/dataset/test/0549b10b2eff42af888dc80bc176eebf.mp4',
#  '/mnt/elice/dataset/test/055e5904fc9d44b8a10078c4cc9f2bac.mp4',
#  '/mnt/elice/dataset/test/0566810acdee4155a1179dc86952ed61.mp4',
#  '/mnt/elice/dataset/test/05744ef7e727432b8e7ff62e182ea15b.mp4',
#  '/mnt/elice/dataset/test/0589a4540c9e4ee0a7359335dd42f3de.mp4',
#  '/mnt/elice/dataset/test/058b50591259472891dba18c91c05e5e.mp4',
#  '/mnt/elice/dataset/test/05946a6b0e584d91b4ea19b3a38631d3.mp4',
#  '/mnt/elice/dataset/test/05a78e5f51a149aca16f20fdb7da93fa.mp4',
#  '/mnt/elice/dataset/test/05b9421c79974b4bb801b532da878eab.mp4',
#  '/mnt/elice/dataset/test/05c23aaf889c4a3a9cd300942978d904.mp4',
#  '/mnt/elice/dataset/test/05f7527ffe064e148e417a8dc99a37a5.mp4',
#  '/mnt/elice/dataset/test/060096d030604ab28da3978bf2e9b0a9.mp4',
#  '/mnt/elice/dataset/test/06139c9a482842369ce87129840bcfc3.mp4',
#  '/mnt/elice/dataset/test/0620aaf0597b474a83e863378481efb5.mp4',
#  '/mnt/elice/dataset/test/062334c0f04a4e7c92806c0ebdc5187b.mp4',
#  '/mnt/elice/dataset/test/066259c3b37f4a51a5a4e4ede80e2192.mp4',
#  '/mnt/elice/dataset/test/068f8344d1cc41ebafb22cd21faa9fdb.mp4',
#  '/mnt/elice/dataset/test/06995202739b44d4b709b7f7b588e195.mp4',
#  '/mnt/elice/dataset/test/06b73c57f4644e01a832ee67013c04f0.mp4',
#  '/mnt/elice/dataset/test/06cf182bd89843d8b48186da4ebc43dd.mp4',
#  '/mnt/elice/dataset/test/06efca615fd049a3bf59c3d565a8d667.mp4',
#  '/mnt/elice/dataset/test/06fb105d8f0344738190cc7756faaa62.mp4',
#  '/mnt/elice/dataset/test/0728cb10b9ab4a4c9a569b6e45ebbe71.mp4',
#  '/mnt/elice/dataset/test/074bb267474a466083ba121adcb895c5.mp4',
#  '/mnt/elice/dataset/test/07559c586d0845beb89982b2efbb377a.mp4',
#  '/mnt/elice/dataset/test/0761b4b2d19c4e74879220c27501e972.mp4',
#  '/mnt/elice/dataset/test/077d04cbfced41c3bc7690e7535136c9.mp4',
#  '/mnt/elice/dataset/test/077d68ad065b420b9836d2d09e3418af.mp4',
#  '/mnt/elice/dataset/test/078319c3b7ad472ca5f8a8bc461b20f2.mp4',
#  '/mnt/elice/dataset/test/07c37b1f1e0c45eca619f5dc52de51b0.mp4',
#  '/mnt/elice/dataset/test/07c84217d4ef42049ff7be639a0ba4bb.mp4',
#  '/mnt/elice/dataset/test/07e38a72874940d580e1950245272e05.mp4',
#  '/mnt/elice/dataset/test/08277645248e47efbf93891732f3030b.mp4',
#  '/mnt/elice/dataset/test/0828c62be6dc48d2940c867af489bf69.mp4',
#  '/mnt/elice/dataset/test/08416e2277ea4c4093f0636d3ed87cf8.mp4',
#  '/mnt/elice/dataset/test/08431808f5e5439ab030a473af8334a2.mp4',
#  '/mnt/elice/dataset/test/084368ceedc64287b50fcb1136764147.mp4',
#  '/mnt/elice/dataset/test/08456efadd2b4855a22c1f3eeedb1ed0.mp4',
#  '/mnt/elice/dataset/test/08474646027b4be487432523019957b1.mp4',
#  '/mnt/elice/dataset/test/084bc115bacf4ea1a6989b533f629be1.mp4',
#  '/mnt/elice/dataset/test/08a04b03cfb94724b889536f7f70e38c.mp4',
#  '/mnt/elice/dataset/test/08a9d455de9d4b27aa1021a1e9d1a1da.mp4',
#  '/mnt/elice/dataset/test/08c1a798cc034fe1a263c4723002755b.mp4',
#  '/mnt/elice/dataset/test/08ec1b734f0f4fb9a1f973210bd0f24f.mp4',
#  '/mnt/elice/dataset/test/090789cc54f648bda844deedbc428f2c.mp4',
#  '/mnt/elice/dataset/test/0919576898c04cb0b5ff26230069112f.mp4',
#  '/mnt/elice/dataset/test/09348df506d949fb8ef5c5fc264e6d24.mp4',
#  '/mnt/elice/dataset/test/09579a1e2d944cf1ab5cb30f78eb65ca.mp4',
#  '/mnt/elice/dataset/test/0968e87d0c5f492db19830fcd39dd1ce.mp4',
#  '/mnt/elice/dataset/test/09765387ea8240fc8ce99205fa49fcda.mp4',
#  '/mnt/elice/dataset/test/097d2f8d05b748499271d8a871b92ab9.mp4',
#  '/mnt/elice/dataset/test/09a67433e0c944dda5f122068f441318.mp4',
#  '/mnt/elice/dataset/test/09a95c8def22474a9de2c0178e90902b.mp4',
#  '/mnt/elice/dataset/test/09c0b1604c0440a79c999187ec9ec63a.mp4',
#  '/mnt/elice/dataset/test/09d630ce149641bdbc90e07e35cc3894.mp4',
#  '/mnt/elice/dataset/test/09eb2476d99345e4a6aa1346ff5f7d9b.mp4',
#  '/mnt/elice/dataset/test/09f6008ac0894d57bafa7ad800dd265c.mp4',
#  '/mnt/elice/dataset/test/09ff296e0159485e971d3b31cf6b8be8.mp4',
#  '/mnt/elice/dataset/test/0a2cd2d8711f49918fb5530d3b16542e.mp4',
#  '/mnt/elice/dataset/test/0a37a8dbd983439fb357bed197bf8808.mp4',
#  '/mnt/elice/dataset/test/0a38135e5ade4b90b07c00ac3ac7be33.mp4',
#  '/mnt/elice/dataset/test/0a5f961248d340e8acf2ec67aa83f431.mp4',
#  '/mnt/elice/dataset/test/0a7b9254f34e4ab1b050eea800394399.mp4',
#  '/mnt/elice/dataset/test/0aa00233d045482285d89aadcf959280.mp4',
#  '/mnt/elice/dataset/test/0aa6eb97ced04e009b1b83b27706bf96.mp4',
#  '/mnt/elice/dataset/test/0ab4f012d579416983fe3571e26bdc16.mp4',
#  '/mnt/elice/dataset/test/0ae0e71f82f444b7bf82725771d24961.mp4',
#  '/mnt/elice/dataset/test/0b03eb36f5254257805ea895b1f22e8b.mp4',
#  '/mnt/elice/dataset/test/0b11cbb318ae4755af76be36da7f981f.mp4',
#  '/mnt/elice/dataset/test/0b16d7286cb24252ba1105fdacd0a891.mp4',
#  '/mnt/elice/dataset/test/0b1754e7f5eb4b0ab2bb040192660775.mp4',
#  '/mnt/elice/dataset/test/0b1eb55c4a0b436f99c42f2fb118c0c2.mp4',
#  '/mnt/elice/dataset/test/0b2d016d7f8d4446a6dd5059bb6350d4.mp4',
#  '/mnt/elice/dataset/test/0b34827d8fd041f8bf86661cce83209c.mp4',
#  '/mnt/elice/dataset/test/0b680f43b1df4b8ab3d9c95a1d994d39.mp4',
#  '/mnt/elice/dataset/test/0b950e63f52443de8d3a13e4fafdbbd2.mp4',
#  '/mnt/elice/dataset/test/0bae0fc9830b48378ada727a1c0d16bd.mp4',
#  '/mnt/elice/dataset/test/0bcb0cbbb5ed4bd2be7323b77484b839.mp4',
#  '/mnt/elice/dataset/test/0bcf4c0806e4419bb55033bebd575696.mp4',
#  '/mnt/elice/dataset/test/0beb882ca47743a780ae0aaa2f606e68.mp4',
#  '/mnt/elice/dataset/test/0bfb3fbf6f604227852a9e240d8b1779.mp4',
#  '/mnt/elice/dataset/test/0c17dd4e25524cab89d2e3165143876d.mp4',
#  '/mnt/elice/dataset/test/0c2f6164c85149bc955d5ccb767516d2.mp4',
#  '/mnt/elice/dataset/test/0c3d4391e6f64045a3c68a96afcafc76.mp4',
#  '/mnt/elice/dataset/test/0c47a18ff3ad40cc9cda51bd82837164.mp4',
#  '/mnt/elice/dataset/test/0c6481bc9ff640c18575af259d43b110.mp4',
#  '/mnt/elice/dataset/test/0c6a008c36064440a9746b87148119f9.mp4',
#  '/mnt/elice/dataset/test/0c87e92b411344fb8f216bece9da93b7.mp4',
#  '/mnt/elice/dataset/test/0ca0b6b7847842c8a0802d781b397645.mp4',
#  '/mnt/elice/dataset/test/0ca6c219a1be461f87796636188d7c55.mp4',
#  '/mnt/elice/dataset/test/0cad5f7b79b54a729602befc8ae87620.mp4',
#  '/mnt/elice/dataset/test/0cd439628efa462386a728924d576857.mp4',
#  '/mnt/elice/dataset/test/0cdb0adf56d84d1aa83147710e5eee5f.mp4',
#  '/mnt/elice/dataset/test/0cedc1e034594b13aa535cb09062c883.mp4',
#  '/mnt/elice/dataset/test/0d3b0cacba384a719e2628fb86741cdc.mp4',
#  '/mnt/elice/dataset/test/0d448fadb3404020b73ad766fdcaffd6.mp4',
#  '/mnt/elice/dataset/test/0d5f52ff7baf413c82a68250a0953ff8.mp4',
#  '/mnt/elice/dataset/test/0d7048b0da5e4f679a58d1e08401f073.mp4',
#  '/mnt/elice/dataset/test/0d937df6965b4a51b0aaba737ac2d72d.mp4',
#  '/mnt/elice/dataset/test/0da4223e93ca4a3598ab58e268f2575d.mp4',
#  '/mnt/elice/dataset/test/0dcf23e29af24fcc8eaf3526876a6e6c.mp4',
#  '/mnt/elice/dataset/test/0dcf508193bb459e81d71afde6bfb051.mp4',
#  '/mnt/elice/dataset/test/0df6fd1e68854dfa88fdc3efe8821e1a.mp4',
#  '/mnt/elice/dataset/test/0e1bc2854c564ea3be4e37a7346023c7.mp4',
#  '/mnt/elice/dataset/test/0e26bf2e35454f29b87f862acf44215f.mp4',
#  '/mnt/elice/dataset/test/0e2ec99ac13f4a4c9b8aceb2226abe46.mp4',
#  '/mnt/elice/dataset/test/0e34e95d028f4265a515b98054578902.mp4',
#  '/mnt/elice/dataset/test/0e40e7bc8258439c9ef22fa6d650d790.mp4',
#  '/mnt/elice/dataset/test/0e8903118af343538596032015817b35.mp4',
#  '/mnt/elice/dataset/test/0ebdb8a3ac4c4da19e3c2521913794e1.mp4',
#  '/mnt/elice/dataset/test/0ec1e06c813e406091f9cb4a7964837d.mp4',
#  '/mnt/elice/dataset/test/0eca7747c11a44ac8928d27822c722ff.mp4',
#  '/mnt/elice/dataset/test/0ecc4ee8cb504fe4af52181e66ae6606.mp4',
#  '/mnt/elice/dataset/test/0ed67ef20f2a46a89cabb5edcc4ee62b.mp4',
#  '/mnt/elice/dataset/test/0ee04392419a46ce82e74b0618782be7.mp4',
#  '/mnt/elice/dataset/test/0eee7d0902364aa89f39830fd7b18fb6.mp4',
#  '/mnt/elice/dataset/test/0eee899c557947d2bde295fdf45a18bc.mp4',
#  '/mnt/elice/dataset/test/0f03553cdbc84101be14c954c9361fd3.mp4',
#  '/mnt/elice/dataset/test/0f05ecf9cf3e47e1bef7d688de325e10.mp4',
#  '/mnt/elice/dataset/test/0f0ce7933a0045e6a3dcd9ddfef08a35.mp4',
#  '/mnt/elice/dataset/test/0f2446dcf6764312a672ac98f1cd0587.mp4',
#  '/mnt/elice/dataset/test/0f28bfd6e71545ebbfeca62f347f5e06.mp4',
#  '/mnt/elice/dataset/test/0f31e74646ec40b7923efb9572d3ff99.mp4',
#  '/mnt/elice/dataset/test/0f4941090fdc436ca8677c7365f4c9ec.mp4',
#  '/mnt/elice/dataset/test/0f4a6959e3434b9ebd6c8ffdf805defa.mp4',
#  '/mnt/elice/dataset/test/0f80897160e24ce1a06000973468de5f.mp4',
#  '/mnt/elice/dataset/test/0f88ada6d7dc418fa2cc5ac839e975ad.mp4',
#  '/mnt/elice/dataset/test/0f9d942a8b3f45aeacd5166a7df33eb1.mp4',
#  '/mnt/elice/dataset/test/0faf880838c545b293d1be99c18cdc8a.mp4',
#  '/mnt/elice/dataset/test/0fbc19cb7ead451cb2dc40db7eab1c9e.mp4',
#  '/mnt/elice/dataset/test/0fd713736a214a0580b4cab055648280.mp4',
#  '/mnt/elice/dataset/test/0fd849b722204689bc0c8005f9ae6b11.mp4',
#  '/mnt/elice/dataset/test/0ffcfea58d6745ce80dd7519ceb9b1d8.mp4',
#  '/mnt/elice/dataset/test/10129e40d3954f2c87dfc8a084f1be42.mp4',
#  '/mnt/elice/dataset/test/1015bbdebd07419ab52756a2b46a9339.mp4',
#  '/mnt/elice/dataset/test/1015da83a8e64b738dbefc1b1eefedd2.mp4',
#  '/mnt/elice/dataset/test/1050b6acf8724ca3aeaa716082dd361e.mp4',
#  '/mnt/elice/dataset/test/10a3407ca6894da584ea1c96d050d8ea.mp4',
#  '/mnt/elice/dataset/test/10a358ec5de34ffbbd8d26182ec433fd.mp4',
#  '/mnt/elice/dataset/test/10afc26a93014b029c6d6354b529109c.mp4',
#  '/mnt/elice/dataset/test/10dcef0be0114c2ca39ca71e7a942d5d.mp4',
#  '/mnt/elice/dataset/test/11773782b26243d8989fc51794ae0670.mp4',
#  '/mnt/elice/dataset/test/1184d7e71f314c80a37244544d5c325d.mp4',
#  '/mnt/elice/dataset/test/11a9f480e22640cba716172e6e76a462.mp4',
#  '/mnt/elice/dataset/test/11e907f73881463b9716ef549e01f609.mp4',
#  '/mnt/elice/dataset/test/11f40f0313914f659e7cc85994d31cc3.mp4',
#  '/mnt/elice/dataset/test/1204c131261645e19e90664cd2dd8774.mp4',
#  '/mnt/elice/dataset/test/120d98dac14a46f59c50dd8ece74c119.mp4',
#  '/mnt/elice/dataset/test/1217685a5bc44ae49c897e825dc2c668.mp4',
#  '/mnt/elice/dataset/test/123bc7f315db42d08130262322964554.mp4',
#  '/mnt/elice/dataset/test/1253d1b9224d4eb6b28bc12ed401b804.mp4',
#  '/mnt/elice/dataset/test/12835487a5ba4302b08d2febbbfd638a.mp4',
#  '/mnt/elice/dataset/test/128baeba10fb438b9fef44372d7a3711.mp4',
#  '/mnt/elice/dataset/test/12bf342fd5db4086963ad3afc7692051.mp4',
#  '/mnt/elice/dataset/test/12df963ce4754881ad289a5f993621c5.mp4',
#  '/mnt/elice/dataset/test/12df9fe31b4d4d98a3adebdcec77c5dd.mp4',
#  '/mnt/elice/dataset/test/12fb00ecb5c045e9b8673f8d2b6779fd.mp4',
#  '/mnt/elice/dataset/test/12ff54e0420e445da46ab72866ccc4c5.mp4',
#  '/mnt/elice/dataset/test/1308e09ce9bc4cd8a6108b5de7cc1a98.mp4',
#  '/mnt/elice/dataset/test/132198731f884623bf86603a1b063e70.mp4',
#  '/mnt/elice/dataset/test/13252d11b4974b3d9b339fec07aaa534.mp4',
#  '/mnt/elice/dataset/test/1335b200808e42ab8244b1db8d3bf678.mp4',
#  '/mnt/elice/dataset/test/134437fad9a0477f92626dfdc4291495.mp4',
#  '/mnt/elice/dataset/test/1357247186014b1282284979b028afb9.mp4',
#  '/mnt/elice/dataset/test/137d227f982d412ba1a9ebe94f730cce.mp4',
#  '/mnt/elice/dataset/test/13d843ddb39f42858e233c7cf9cab6a9.mp4',
#  '/mnt/elice/dataset/test/13d8962bfd994a06ba21eaa1d4a77da4.mp4',
#  '/mnt/elice/dataset/test/13e60b0519704ab1b4491d1b84c279da.mp4',
#  '/mnt/elice/dataset/test/13ef2d9c71234e189d6358b3919725bf.mp4',
#  '/mnt/elice/dataset/test/13f9c508361448f19dce41af00459876.mp4',
#  '/mnt/elice/dataset/test/142b0eb726d440e380aa673fed4b276b.mp4',
#  '/mnt/elice/dataset/test/1435bff35bc0433db4ed8a2e91203d8f.mp4',
#  '/mnt/elice/dataset/test/144a8b55603049089198d4f2aea667f6.mp4',
#  '/mnt/elice/dataset/test/1478d67c6418423fbd890a10c7048baf.mp4',
#  '/mnt/elice/dataset/test/147ef3b62df2486eabcc3bf39ee74170.mp4',
#  '/mnt/elice/dataset/test/1482fc7b00884e47bdd7fcc1d53fe1c0.mp4',
#  '/mnt/elice/dataset/test/14914a1594824364a9bb4cd061fec9ae.mp4',
#  '/mnt/elice/dataset/test/14c190cb63b14ca883ade2775ebd722f.mp4',
#  '/mnt/elice/dataset/test/14cc7227de444f5799d24cfe26fff590.mp4',
#  '/mnt/elice/dataset/test/14d3f76a11454ba4b3947c297d312784.mp4',
#  '/mnt/elice/dataset/test/14e123e635bf4c7291acf1047cd00d11.mp4',
#  '/mnt/elice/dataset/test/1501fb9a346d4c3f9da10a80693b230f.mp4',
#  '/mnt/elice/dataset/test/1512d1f91b3c462d86bc605f49fe5d5f.mp4',
#  '/mnt/elice/dataset/test/151f6578ffbb414793f6214988ac8564.mp4',
#  '/mnt/elice/dataset/test/154e24c384d44314994d41efe9cfed92.mp4',
#  '/mnt/elice/dataset/test/1577159d9b5848caa506737044b92a49.mp4',
#  '/mnt/elice/dataset/test/15c62160b5d747039b27913e5012259e.mp4',
#  '/mnt/elice/dataset/test/15cd59275933467e9322338f0084c977.mp4',
#  '/mnt/elice/dataset/test/15fa141033fb4eb89a441767117101a4.mp4',
#  '/mnt/elice/dataset/test/1600049d3d9a4eba822be35dddce9ceb.mp4',
#  '/mnt/elice/dataset/test/160ed096e9ca4095a06c982d511ed137.mp4',
#  '/mnt/elice/dataset/test/160fbe73109344f193ddfddcc292441e.mp4',
#  '/mnt/elice/dataset/test/164ee358d1244427a902285784dedbbf.mp4',
#  '/mnt/elice/dataset/test/16599c2c3851472c86b7d53786af40a4.mp4',
#  '/mnt/elice/dataset/test/165f6ef3a3194cae866f52c242537510.mp4',
#  '/mnt/elice/dataset/test/1668e9562d4044dda98e7e9c2a4812c4.mp4',
#  '/mnt/elice/dataset/test/166d19b9712f493ea55e12437e06849d.mp4',
#  '/mnt/elice/dataset/test/167af86be00843d5b903f7f3d4dc7516.mp4',
#  '/mnt/elice/dataset/test/167d804166b8487b85cc6f18fde6077d.mp4',
#  '/mnt/elice/dataset/test/169e1c4aad564a6b8bd32eab851b77c8.mp4',
#  '/mnt/elice/dataset/test/16afd02eec98428a9a6bc72a1fd20df4.mp4',
#  '/mnt/elice/dataset/test/16c1cb6165584f3eafe25f578c77a488.mp4',
#  '/mnt/elice/dataset/test/16c71f0fafd5467d9c8063d8858383e2.mp4',
#  '/mnt/elice/dataset/test/16cc07074bd049c38157758ac1e69739.mp4',
#  '/mnt/elice/dataset/test/16e78b0c03e1494a85fe2e951970eab6.mp4',
#  '/mnt/elice/dataset/test/17694d6c54a84b5c9372e8c4b994cc17.mp4',
#  '/mnt/elice/dataset/test/1779a34c654241b49093d3711d18f312.mp4',
#  '/mnt/elice/dataset/test/17974875f7bf4d5f8613b4afc703ac44.mp4',
#  '/mnt/elice/dataset/test/18148e71c30a4950a7a803e8e9b6d178.mp4',
#  '/mnt/elice/dataset/test/181d1c550f324da8a354a2fbfd72e971.mp4',
#  '/mnt/elice/dataset/test/1826f1eef011456e854b8850ac3827ca.mp4',
#  '/mnt/elice/dataset/test/1827aeba6e4248c5a8d82252601142f6.mp4',
#  '/mnt/elice/dataset/test/184c821491064bd99da33c9cb72a725a.mp4',
#  '/mnt/elice/dataset/test/184ec8227f9844d7a137ad2dc46dbcc2.mp4',
#  '/mnt/elice/dataset/test/1862213eeafe48b88f511a3aa0c984f9.mp4',
#  '/mnt/elice/dataset/test/1899b3edd31948e5a47afa6f0d6b3924.mp4',
#  '/mnt/elice/dataset/test/18aec65ec10f47dca62b048ad38ba3fa.mp4',
#  '/mnt/elice/dataset/test/18bce443d8f94548ba985e6b9257cc06.mp4',
#  '/mnt/elice/dataset/test/18c8048207314cd58aa32314cfb0ba19.mp4',
#  '/mnt/elice/dataset/test/18ccacff28c94dcfbeb6c6ed0c561fdf.mp4',
#  '/mnt/elice/dataset/test/18f93f197ff34a839da6e46c3903f9a0.mp4',
#  '/mnt/elice/dataset/test/190b162a1b954a8f8a0f6cf0c2936ba6.mp4',
#  '/mnt/elice/dataset/test/19816cf7f19341dfa9c94c184423445f.mp4',
#  '/mnt/elice/dataset/test/1992bb4a0bf34c7aa5d6ababc6451ead.mp4',
#  '/mnt/elice/dataset/test/1993f5c1c181416f9deddbd8a00b5dd0.mp4',
#  '/mnt/elice/dataset/test/19a71e931fa84698b5610bff23ca53a7.mp4',
#  '/mnt/elice/dataset/test/19d0a6f20fee495f9e1f866bfd3b95b4.mp4',
#  '/mnt/elice/dataset/test/19fc9c628a344bc5a6ac864aa9a98b94.mp4',
#  '/mnt/elice/dataset/test/19fce98b2bb94ed5abdeea92720f3914.mp4',
#  '/mnt/elice/dataset/test/1a1573b30f164f40b0b4b6c7d87e4d3c.mp4',
#  '/mnt/elice/dataset/test/1a1ffd7438d347179448b0e84ee79cc9.mp4',
#  '/mnt/elice/dataset/test/1a2217bc32724670afc58f0e9953d449.mp4',
#  '/mnt/elice/dataset/test/1a33f29e164f469f9353bc4ad5fb09b7.mp4',
#  '/mnt/elice/dataset/test/1a3da2dfbbf940c79c8bec70247816e7.mp4',
#  '/mnt/elice/dataset/test/1a529f117c964f4b8a4a4efda058ed9d.mp4',
#  '/mnt/elice/dataset/test/1a59117854454186bc97d2006cfa7e33.mp4',
#  '/mnt/elice/dataset/test/1a607c0a82e4470698ad3e17fbac4399.mp4',
#  '/mnt/elice/dataset/test/1a819ac4658d4458b483f3931e1ba411.mp4',
#  '/mnt/elice/dataset/test/1a8fc372a762490494834775973c3591.mp4',
#  '/mnt/elice/dataset/test/1a95e86fd7b44147bc55589aaae170d4.mp4',
#  '/mnt/elice/dataset/test/1a9ace3a081d4a24b108842057d8fe41.mp4',
#  '/mnt/elice/dataset/test/1a9b62b76d0341e0a8ec2f9510740dbc.mp4',
#  '/mnt/elice/dataset/test/1aab4ffc9b2a44a0ad5c0956ebaef46f.mp4',
#  '/mnt/elice/dataset/test/1aba6713bbc444d99c06d7c6a9985f06.mp4',
#  '/mnt/elice/dataset/test/1ac6851b5f5e4e7ab189bcf4191b142e.mp4',
#  '/mnt/elice/dataset/test/1acaf4915e7042ee8a4ab7bacf46bfa3.mp4',
#  '/mnt/elice/dataset/test/1ae434cb1ede4d439682f9a4c7dc1289.mp4',
#  '/mnt/elice/dataset/test/1b2ea4718cb94a068cbfa9e28f7d06b9.mp4',
#  '/mnt/elice/dataset/test/1b37a963cf4f4b5aa34ab96e113f872b.mp4',
#  '/mnt/elice/dataset/test/1b48aa1042bb467e82d3ec5a21fbeb28.mp4',
#  '/mnt/elice/dataset/test/1b62900b1eeb42819ffb664e9eb4212d.mp4',
#  '/mnt/elice/dataset/test/1b8293fd85ca411fab6c2e7c6e3561ad.mp4',
#  '/mnt/elice/dataset/test/1b8721bbc01c4431b60247cf0755465f.mp4',
#  '/mnt/elice/dataset/test/1b94c7f0262141b4bd59fdb480edc40b.mp4',
#  '/mnt/elice/dataset/test/1bad86f5125d457998364ad68948d6e7.mp4',
#  '/mnt/elice/dataset/test/1bafcfebbdbc48e8a8e87d0c67708e8e.mp4',
#  '/mnt/elice/dataset/test/1bf2533e928c4d7c813ea9c8e043b12a.mp4',
#  '/mnt/elice/dataset/test/1c135123fad84f10ae6bb17bc54593a4.mp4',
#  '/mnt/elice/dataset/test/1c336a91c6024318bf981f0bb64c6ecd.mp4',
#  '/mnt/elice/dataset/test/1c36a8dfa9004ede8c6343ff413ef01a.mp4',
#  '/mnt/elice/dataset/test/1c6d412e684940d7b1bc7f7ad0aed1a8.mp4',
#  '/mnt/elice/dataset/test/1c6fc6508ea944fdbe263d9ae1751d8a.mp4',
#  '/mnt/elice/dataset/test/1ca485a4215d4f0598ba33f3e9e025c6.mp4',
#  '/mnt/elice/dataset/test/1cc074c4d59e42d1ac260647ff06a307.mp4',
#  '/mnt/elice/dataset/test/1cfb2a369efe4adb8c0623312d3ea77a.mp4',
#  '/mnt/elice/dataset/test/1d0451df2e73406fbaf09bc0133e6b2e.mp4',
#  '/mnt/elice/dataset/test/1d08476dd1d54bc0a045010475f2ca66.mp4',
#  '/mnt/elice/dataset/test/1d2079ea765b4877a955c419c710eed8.mp4',
#  '/mnt/elice/dataset/test/1d257197e6d24befb3d512719982bbf5.mp4',
#  '/mnt/elice/dataset/test/1d418e794a284b719a3ce3b01a0d3b8d.mp4',
#  '/mnt/elice/dataset/test/1d4283e1181c45799921a23842855e43.mp4',
#  '/mnt/elice/dataset/test/1d6b5088888f4fafa805c81d7a6785be.mp4',
#  '/mnt/elice/dataset/test/1d79287028c240e4ad9ade824338fbd5.mp4',
#  '/mnt/elice/dataset/test/1d7d9e9e77c4400eb57658f86d0cdf13.mp4',
#  '/mnt/elice/dataset/test/1d804733b55c49468ee52539bcfed93f.mp4',
#  '/mnt/elice/dataset/test/1d8a331863d44751a11d371068690105.mp4',
#  '/mnt/elice/dataset/test/1d8b13e0b5674b6bb6eb2ef7855f298d.mp4',
#  '/mnt/elice/dataset/test/1dcad7f51b214de0bfe674c8325389e2.mp4',
#  '/mnt/elice/dataset/test/1dd773a98adb4b9f9c2526b7641ff75d.mp4',
#  '/mnt/elice/dataset/test/1de39da3d07a489f89a6c274e0551fac.mp4',
#  '/mnt/elice/dataset/test/1deae3697b254a3e9eb6ed97afc2e809.mp4',
#  '/mnt/elice/dataset/test/1df84f96a0c646ba93fbe4fd00569e81.mp4',
#  '/mnt/elice/dataset/test/1e18bed2809c4569bf4f0275f6f30fec.mp4',
#  '/mnt/elice/dataset/test/1e2d13228a0740588fdef401d335ecaa.mp4',
#  '/mnt/elice/dataset/test/1e600dbbbd3b4c7d97aaebde58d333f8.mp4',
#  '/mnt/elice/dataset/test/1e7adcd3cf4a42d9af5975ddee681d56.mp4',
#  '/mnt/elice/dataset/test/1e898997ff8e4ac3a44aa80708f2397e.mp4',
#  '/mnt/elice/dataset/test/1e953158a09e4b0daabe365e36cf0d70.mp4',
#  '/mnt/elice/dataset/test/1ed7b0d548b84e38b3a990db0ae0b592.mp4',
#  '/mnt/elice/dataset/test/1ef6cae8b40249e5a800284f1b38ab20.mp4',
#  '/mnt/elice/dataset/test/1f10340080ee47ed91ccc3fd03540ca7.mp4',
#  '/mnt/elice/dataset/test/1f19b771a4564f42872de7419cffff61.mp4',
#  '/mnt/elice/dataset/test/1f23a74e065f4a978c9b30d87ab6c69b.mp4',
#  '/mnt/elice/dataset/test/1f372c244dab4c41a857fe87c26ed086.mp4',
#  '/mnt/elice/dataset/test/1f473e60ffef4543b96b181bee04d969.mp4',
#  '/mnt/elice/dataset/test/1f7bde906c9445cb9e49567fd6c3cb00.mp4',
#  '/mnt/elice/dataset/test/1f87783890334ae8b55d076c94464fcc.mp4',
#  '/mnt/elice/dataset/test/1f923aeb528146418473ee5ee4689df9.mp4',
#  '/mnt/elice/dataset/test/1f9dd934782a491f953b055f90e54c02.mp4',
#  '/mnt/elice/dataset/test/1fb714588eb84d4880c2ad158e8d199d.mp4',
#  '/mnt/elice/dataset/test/1fbfeb5df26e41c0a9a0d07e523218bc.mp4',
#  '/mnt/elice/dataset/test/1fdbe2c9ca434eeb9db468f1786ddfa1.mp4',
#  '/mnt/elice/dataset/test/1fdc0eda26a24c7e824558ee8d24e56d.mp4',
#  '/mnt/elice/dataset/test/1fe5f7f9f7aa4151905d29dbf1c46cb4.mp4',
#  '/mnt/elice/dataset/test/1fe90872427b4c878afbb17c3837ea61.mp4',
#  '/mnt/elice/dataset/test/200fc19337d84d658216c5760a0efc4e.mp4',
#  '/mnt/elice/dataset/test/200fd7f4d109438a8dfe496d71828903.mp4',
#  '/mnt/elice/dataset/test/2040539f7a6f41f5b00f3aaa9ce7fdca.mp4',
#  '/mnt/elice/dataset/test/205501ae478e4bdab512ec5e25957128.mp4',
#  '/mnt/elice/dataset/test/206382f629b44e09820db0079b209a23.mp4',
#  '/mnt/elice/dataset/test/2071f3457dfd47d8a617161b361d038e.mp4',
#  '/mnt/elice/dataset/test/20ac70518557459c9ca3dfa57906b5ab.mp4',
#  '/mnt/elice/dataset/test/20bbc70372f64df28e81974a19f229a1.mp4',
#  '/mnt/elice/dataset/test/211c72d578f647b39e69a79feae20ced.mp4',
#  '/mnt/elice/dataset/test/213c744e710c400ab2f17f857d93b4ac.mp4',
#  '/mnt/elice/dataset/test/21503cc704b44d8db15cd6a5aac2aa34.mp4',
#  '/mnt/elice/dataset/test/21787584832642fd981d580e5b0c2b66.mp4',
#  '/mnt/elice/dataset/test/21948b0182094e3db7850d84b647ea83.mp4',
#  '/mnt/elice/dataset/test/21a1375941e24cb39305e08374c17e36.mp4',
#  '/mnt/elice/dataset/test/21a2c62b7fa54d74ac1cebba22318300.mp4',
#  '/mnt/elice/dataset/test/21ac5d2b9c4a4d998cb42b83ec2fa451.mp4',
#  '/mnt/elice/dataset/test/21b0cd23dc09496eaf197cbc227e572d.mp4',
#  '/mnt/elice/dataset/test/21c2a237529b440db661592f64e67f1f.mp4',
#  '/mnt/elice/dataset/test/21c6fe44c4894b6d8b451cf054f0ecaf.mp4',
#  '/mnt/elice/dataset/test/21c7f0c8f9c5433d80250995febb5605.mp4',
#  '/mnt/elice/dataset/test/21dd793bb9564132a6544aca86e9b489.mp4',
#  '/mnt/elice/dataset/test/21ddee1ee47545a4b6d08b3b0db0d785.mp4',
#  '/mnt/elice/dataset/test/21e13b97f27f4e30a9770d82b1a987c3.mp4',
#  '/mnt/elice/dataset/test/21e6674be7d24568aa444b17ca12adcb.mp4',
#  '/mnt/elice/dataset/test/21edab7aac39490a91e1707ce138f9ab.mp4',
#  '/mnt/elice/dataset/test/224a181d91b94393a2cfd3c074bb7a0a.mp4',
#  '/mnt/elice/dataset/test/224b9bfaa9aa4cabbd2d0a8b574f08a7.mp4',
#  '/mnt/elice/dataset/test/2269fbf376ce4ecfaae682d32faeb604.mp4',
#  '/mnt/elice/dataset/test/229a00bfd45d4cce881ddd8fb340bba0.mp4',
#  '/mnt/elice/dataset/test/2310d4abf24b4a749d09d8e945e312a8.mp4',
#  '/mnt/elice/dataset/test/231c9a4c80d14531a5cadfd24d70b620.mp4',
#  '/mnt/elice/dataset/test/233ad58892994ffe926218eda94132f0.mp4',
#  '/mnt/elice/dataset/test/23432afdd2dd4f52829ac6dced904ef0.mp4',
#  '/mnt/elice/dataset/test/2348c84b157d4e75812401660cb4c7f2.mp4',
#  '/mnt/elice/dataset/test/2356398397194e13a80cd2d700e6758e.mp4',
#  '/mnt/elice/dataset/test/2378ddd0686148fe94010aa16945223c.mp4',
#  '/mnt/elice/dataset/test/2391613e5b8f4fb18ad45635ac7fc53a.mp4',
#  '/mnt/elice/dataset/test/23b4f33014f345b29d92bd34313c5967.mp4',
#  '/mnt/elice/dataset/test/23d4e0e1efd949379067651d822bebce.mp4',
#  '/mnt/elice/dataset/test/23da8e2fa477469993c0bec49b37136c.mp4',
#  '/mnt/elice/dataset/test/23e55ebf6bde4ed293bbcd793210cc89.mp4',
#  '/mnt/elice/dataset/test/23f60fe52cce4918b24c38cb0f3173fb.mp4',
#  '/mnt/elice/dataset/test/24189f2e86d34d4d8b7224434defc886.mp4',
#  '/mnt/elice/dataset/test/242102864fc84a0984674796de1a14f3.mp4',
#  '/mnt/elice/dataset/test/245ab6ded8fc4124a978506e90f027f2.mp4',
#  '/mnt/elice/dataset/test/245cd9c766b347a2b30e4756bb847fcc.mp4',
#  '/mnt/elice/dataset/test/24650b220ef845c2b35c5c254eef652b.mp4',
#  '/mnt/elice/dataset/test/248b98ec995c4deabf96f3d66402a3e7.mp4',
#  '/mnt/elice/dataset/test/24b7708c54e549a8955a0e3760f2b182.mp4',
#  '/mnt/elice/dataset/test/24e671fcaa7a4b20933cd0a20aef65ab.mp4',
#  '/mnt/elice/dataset/test/24eed39f46144f83bfd0e356e6fb2ae0.mp4',
#  '/mnt/elice/dataset/test/25091064656c499d8418c0b63bc41002.mp4',
#  '/mnt/elice/dataset/test/250e90a94aa24deeb11be793edd71025.mp4',
#  '/mnt/elice/dataset/test/251452e3198646ceae97838c59b9f11f.mp4',
#  '/mnt/elice/dataset/test/2523a6aa314844e8a7d02ebefd8bc318.mp4',
#  '/mnt/elice/dataset/test/2536829fe93f48c39069d4017fa8d19c.mp4',
#  '/mnt/elice/dataset/test/25392221f4764a808c0ee1d6367bf79b.mp4',
#  '/mnt/elice/dataset/test/2574b9610c264e5588a3adec81683de3.mp4',
#  '/mnt/elice/dataset/test/258c62a5e8db41ec9fba379476edcff9.mp4',
#  '/mnt/elice/dataset/test/25acff2f22ce451695baf22dbbd165a2.mp4',
#  '/mnt/elice/dataset/test/25c2ee37a1f84386a5a5ee2da174fce7.mp4',
#  '/mnt/elice/dataset/test/25c733ac2e3c4fb3976c43e8c84b5801.mp4',
#  '/mnt/elice/dataset/test/25efabbfa76748aba0f00c1a177cd40c.mp4',
#  '/mnt/elice/dataset/test/266a86726c6a4d0b99c401064ecc0404.mp4',
#  '/mnt/elice/dataset/test/266aacd65c794e2aaba5f248fb3927e4.mp4',
#  '/mnt/elice/dataset/test/26781caff8244e40898af4e281aa1054.mp4',
#  '/mnt/elice/dataset/test/2680d28042204c72849b89ee8c3630e3.mp4',
#  '/mnt/elice/dataset/test/26869419062e4ea9b9721dc31f84ffb3.mp4',
#  '/mnt/elice/dataset/test/26a057c84be54687a23307be79854c53.mp4',
#  '/mnt/elice/dataset/test/26a9ba2e084e478fa45366eb9536caac.mp4',
#  '/mnt/elice/dataset/test/26ceb386459241b38dfb120bd099919b.mp4',
#  '/mnt/elice/dataset/test/26d6c37743f84edf9d49192619e36c00.mp4',
#  '/mnt/elice/dataset/test/27170aa396b3474d8946488d6626cbf5.mp4',
#  '/mnt/elice/dataset/test/27229dba7a10438d891eec4c892e5cba.mp4',
#  '/mnt/elice/dataset/test/272668e764144ae8b7f945424b6de917.mp4',
#  '/mnt/elice/dataset/test/274ffb35d0ec45cdbcb2ae375f010d3d.mp4',
#  '/mnt/elice/dataset/test/277077c4126a4df39f8f21ffda55c69b.mp4',
#  '/mnt/elice/dataset/test/27948afc29da49c6823fffa153a1dacf.mp4',
#  '/mnt/elice/dataset/test/27af3609ca054aeb9430f51770678a61.mp4',
#  '/mnt/elice/dataset/test/27f9e60d4e84405d88fde5351e19d6db.mp4',
#  '/mnt/elice/dataset/test/28348f3783954941be84906168b2ffc3.mp4',
#  '/mnt/elice/dataset/test/2835cd14d282450f913c8b8c7d7377bd.mp4',
#  '/mnt/elice/dataset/test/28408856fabe448282ef60dabcb2a528.mp4',
#  '/mnt/elice/dataset/test/284adb8cde3c478a8c51125c7c497e93.mp4',
#  '/mnt/elice/dataset/test/28d8ed4650a7479dbe0af258dd29f3bc.mp4',
#  '/mnt/elice/dataset/test/28e363100b554639b328ff713c79c619.mp4',
#  '/mnt/elice/dataset/test/28ef75c4e8334c8c9fba448d341f8a41.mp4',
#  '/mnt/elice/dataset/test/28f0b670513d4558af496f7e0d816733.mp4',
#  '/mnt/elice/dataset/test/2908a5e7c6fc468f8ab5f393bff0b6c5.mp4',
#  '/mnt/elice/dataset/test/298e7bb2328647ed9b1d33a8381b8c91.mp4',
#  '/mnt/elice/dataset/test/2995face9bd445e39434612fc34d30f4.mp4',
#  '/mnt/elice/dataset/test/29c7fb47ce9741ba9d98a3e27482fae8.mp4',
#  '/mnt/elice/dataset/test/29eb5e839bab4ad4943372b6ee6afa79.mp4',
#  '/mnt/elice/dataset/test/29f23a6016a34d72bb436c4446781a75.mp4',
#  '/mnt/elice/dataset/test/29fe7fffb59f46c6b2270b0bf3da27c1.mp4',
#  '/mnt/elice/dataset/test/2a0b5d0cf4534312b84c8904092e47ba.mp4',
#  '/mnt/elice/dataset/test/2a0de61eeaf14ea7a5d9dc5a2f8eee56.mp4',
#  '/mnt/elice/dataset/test/2a12d86de53d4387a212663f98f57c01.mp4',
#  '/mnt/elice/dataset/test/2a2150e6a98845f596a354248b1e95a2.mp4',
#  '/mnt/elice/dataset/test/2a2318ba2ca14ca49396c33fb4bf3239.mp4',
#  '/mnt/elice/dataset/test/2a434eb08c8d46a8a75af9114e667733.mp4',
#  '/mnt/elice/dataset/test/2a50e570ffa044b9aea8c7bc753fdf3e.mp4',
#  '/mnt/elice/dataset/test/2a57e08ed15e4937aa569c333c9e7632.mp4',
#  '/mnt/elice/dataset/test/2a91e851a95144e59870891a7975ecb2.mp4',
#  '/mnt/elice/dataset/test/2aaa8828dc5e449da31f8fdb2e8e06ae.mp4',
#  '/mnt/elice/dataset/test/2ab0b16d14894477afc45a3145c73ad0.mp4',
#  '/mnt/elice/dataset/test/2abb20f5a3154847afa0444d43a96545.mp4',
#  '/mnt/elice/dataset/test/2adb6076515a45c2a6f8f74e0e1fd1c8.mp4',
#  '/mnt/elice/dataset/test/2afa815483824c39b643604b2642ffbd.mp4',
#  '/mnt/elice/dataset/test/2b15b82ccb2247c29f63e04f1047d49c.mp4',
#  '/mnt/elice/dataset/test/2b19e8a7230b4b9a851b99022702b947.mp4',
#  '/mnt/elice/dataset/test/2b20ba25340e4ec1b9fb6ecff0f8ea49.mp4',
#  '/mnt/elice/dataset/test/2b2d95c940b1411cb327e88e1c98be3b.mp4',
#  '/mnt/elice/dataset/test/2b52953f457b4283a5ed10df1b379449.mp4',
#  '/mnt/elice/dataset/test/2b69d94554d24ea69cdc786a644594cb.mp4',
#  '/mnt/elice/dataset/test/2b76ec58dffc4f8f9602b05ac4b7f86f.mp4',
#  '/mnt/elice/dataset/test/2b9515ea0c20471a82802857e617c65f.mp4',
#  '/mnt/elice/dataset/test/2b9ea10ba21b40f2bf1bb6623571b741.mp4',
#  '/mnt/elice/dataset/test/2ba7cdc643e74b05bab38c3ddc4a6802.mp4',
#  '/mnt/elice/dataset/test/2bb39ccdeb884b059ecdfbcdfd668eb3.mp4',
#  '/mnt/elice/dataset/test/2bc1a517b4a640bebd4e426ff4450971.mp4',
#  '/mnt/elice/dataset/test/2bcae2e5366141ad960749c038aece8a.mp4',
#  '/mnt/elice/dataset/test/2bda61f29186438a935802f806d8078f.mp4',
#  '/mnt/elice/dataset/test/2bdd8ff877be456c85b153e8833054c5.mp4',
#  '/mnt/elice/dataset/test/2bfb1342278243b59f4783c34c05b62a.mp4',
#  '/mnt/elice/dataset/test/2bff5a42866d4ba68d4e17dbb2887eed.mp4',
#  '/mnt/elice/dataset/test/2c071d6c07f54a8d97d0579d9465966d.mp4',
#  '/mnt/elice/dataset/test/2c66996701714051a6cd1be1a715cbd0.mp4',
#  '/mnt/elice/dataset/test/2c78c5849b9e4087808ca42921c404ca.mp4',
#  '/mnt/elice/dataset/test/2c9537875d5e4a1fb53249870baa47d7.mp4',
#  '/mnt/elice/dataset/test/2c96466c4f8547c897c11df54093b0ca.mp4',
#  '/mnt/elice/dataset/test/2caf5edf0dc0418abd2f0ad1d3d71522.mp4',
#  '/mnt/elice/dataset/test/2cb4fc44478e4db1b4adae1b201a572d.mp4',
#  '/mnt/elice/dataset/test/2cd7ce09f73d48f486ce1d89e9471b2a.mp4',
#  '/mnt/elice/dataset/test/2cdb03e5dc8f47b1b89c61da89f0af41.mp4',
#  '/mnt/elice/dataset/test/2cf62a7510624a998eab2231247a0868.mp4',
#  '/mnt/elice/dataset/test/2d0ad2a5fdff4a08858e252f979414ce.mp4',
#  '/mnt/elice/dataset/test/2d188fd30bd14e21a2663e0a56da92ab.mp4',
#  '/mnt/elice/dataset/test/2d68a91244b34389b2e86ec6621ed0a7.mp4',
#  '/mnt/elice/dataset/test/2d8bd98a973b488ab3a407628121a524.mp4',
#  '/mnt/elice/dataset/test/2d9a7d300e6f43f7913497c929730712.mp4',
#  '/mnt/elice/dataset/test/2da4034516db437d9611bcf8285ec16b.mp4',
#  '/mnt/elice/dataset/test/2db1e0ea3c8b42baad1955fe6b7fce35.mp4',
#  '/mnt/elice/dataset/test/2dc239de671c4dc6ad67e7efe0b53ba4.mp4',
#  '/mnt/elice/dataset/test/2dd17e2fa1064da294277e6120f384ab.mp4',
#  '/mnt/elice/dataset/test/2de2a87d725048c4912f9cefe5f012e3.mp4',
#  '/mnt/elice/dataset/test/2de2bbbda22942c0b112c1387eddad2a.mp4',
#  '/mnt/elice/dataset/test/2e068aa9f02240d3acd94a9a2f331bef.mp4',
#  '/mnt/elice/dataset/test/2e2ab440d2fe4fb3b6cc59e6c7becba2.mp4',
#  '/mnt/elice/dataset/test/2e5d42c4cd5d4dfa960e4e11d306566b.mp4',
#  '/mnt/elice/dataset/test/2e6cf97fc9944c1ebdd8b72598684b71.mp4',
#  '/mnt/elice/dataset/test/2e6e599db161490bad99fc7449092b6c.mp4',
#  '/mnt/elice/dataset/test/2e9211e7643e4b679d142c22d75ac4c3.mp4',
#  '/mnt/elice/dataset/test/2eb0e7c706ee4ee985cab5d75a26ad94.mp4',
#  '/mnt/elice/dataset/test/2ef1c2538fda4c0cba278645171bf589.mp4',
#  '/mnt/elice/dataset/test/2efb159b7dd04c16b743b6ebdce803bc.mp4',
#  '/mnt/elice/dataset/test/2f01880657d340739beaf78432d5353e.mp4',
#  '/mnt/elice/dataset/test/2f132e070e4741309e2530b90ad80bd8.mp4',
#  '/mnt/elice/dataset/test/2f55bd5a0e29434d9ff8b0b4136a9728.mp4',
#  '/mnt/elice/dataset/test/2f5ee75931ad4706a25bf69ad9d99ffe.mp4',
#  '/mnt/elice/dataset/test/2f7d88e5d52244299ab134a210838e8c.mp4',
#  '/mnt/elice/dataset/test/2fa1cd8bbe7f4535bd8090211fbbdc75.mp4',
#  '/mnt/elice/dataset/test/2fa209bba6f4440d9e58837b24487949.mp4',
#  '/mnt/elice/dataset/test/2facda4bc94b4f3aa697943b9e6f2dc3.mp4',
#  '/mnt/elice/dataset/test/2fb93ad5a50d414d8970ad0efacec355.mp4',
#  '/mnt/elice/dataset/test/2fc7a4e455604708840a3837eeadea01.mp4',
#  '/mnt/elice/dataset/test/2fcfa9607aa84d5ea509dd3161266af7.mp4',
#  '/mnt/elice/dataset/test/2fd645ed4d7645ad8f571d5edcb352b6.mp4',
#  '/mnt/elice/dataset/test/2fd7f7fdf09c4f06a023765bc0b64803.mp4',
#  '/mnt/elice/dataset/test/2fd8f2f06764479e8755d506954a1bc8.mp4',
#  '/mnt/elice/dataset/test/2ff2cf92fb6e4e28a0888dbcbb751b8a.mp4',
#  '/mnt/elice/dataset/test/2ff6e62ecf0f487e9d73e478bd12dbb7.mp4',
#  '/mnt/elice/dataset/test/3001ed3072404393bc79c22ac22ab956.mp4',
#  '/mnt/elice/dataset/test/3040225b2d394689b5b65b0328bfcb8f.mp4',
#  '/mnt/elice/dataset/test/306992e5c2b743e28b457239b2a88f0b.mp4',
#  '/mnt/elice/dataset/test/306de00ed90e44bdad7dad9df8ff940f.mp4',
#  '/mnt/elice/dataset/test/306e82763b7b4063b417819260083d0f.mp4',
#  '/mnt/elice/dataset/test/308055c8088044a7b71dd211be3e44f8.mp4',
#  '/mnt/elice/dataset/test/308ed642c1864b97ab85b1264c6ff14b.mp4',
#  '/mnt/elice/dataset/test/30965a84cb0f48f99b8f63763879e614.mp4',
#  '/mnt/elice/dataset/test/3098b22a12e84c79bc7871006579bfbf.mp4',
#  '/mnt/elice/dataset/test/30ac50fd245a4a33a0f11e7804f3fedd.mp4',
#  '/mnt/elice/dataset/test/30b49200635547c28a55e43351f290e0.mp4',
#  '/mnt/elice/dataset/test/310abfd2c5554af79ef6ce3f482b09b0.mp4',
#  '/mnt/elice/dataset/test/310bf859db0941f4815a462544ed3f9b.mp4',
#  '/mnt/elice/dataset/test/31359715998f4a3aa2d9a7d9feb472a8.mp4',
#  '/mnt/elice/dataset/test/314a12452db247e1b57e588305e840ac.mp4',
#  '/mnt/elice/dataset/test/316a20ac378b44d89a7e3348a163ca3d.mp4',
#  '/mnt/elice/dataset/test/31905fc9db024981ad149fb22df2dd0a.mp4',
#  '/mnt/elice/dataset/test/31ab370f92d5488a9c103a6522aa5298.mp4',
#  '/mnt/elice/dataset/test/31ca60fef33a44d5a158ac58e2aa3ea6.mp4',
#  '/mnt/elice/dataset/test/31d7ae9c0abe4c5e9ed8d9f082f2a7ac.mp4',
#  '/mnt/elice/dataset/test/320b670a4298434db995afa0b626cd38.mp4',
#  '/mnt/elice/dataset/test/3228425f26b5440da86c2264555d7f68.mp4',
#  '/mnt/elice/dataset/test/32310b57975f401f9ac0ca8bf791b8ef.mp4',
#  '/mnt/elice/dataset/test/323d815d6f1c47d19f01857da710fee2.mp4',
#  '/mnt/elice/dataset/test/32404007d8cb401395c478d8c3c5d4a1.mp4',
#  '/mnt/elice/dataset/test/32558798e18c4cb288561d2c2a9bd44f.mp4',
#  '/mnt/elice/dataset/test/3272b07c04724f91ba37b162d413b51c.mp4',
#  '/mnt/elice/dataset/test/327df6bd768d4d1d935f4db38be804d9.mp4',
#  '/mnt/elice/dataset/test/3291ecab38e54d7a9eb99f3e03d6c37e.mp4',
#  '/mnt/elice/dataset/test/329ddb1096ae42949e9b052ac5ba3954.mp4',
#  '/mnt/elice/dataset/test/32a7057999e9449e92dabbdd61251dcd.mp4',
#  '/mnt/elice/dataset/test/32a93c848ba54d1d8a03dbd8b4a8ce55.mp4',
#  '/mnt/elice/dataset/test/32c71ea06b2b42f0acc97f55fd3fc8db.mp4',
#  '/mnt/elice/dataset/test/32d324642af0459eba6f9a5fc1006a84.mp4',
#  '/mnt/elice/dataset/test/32d414234b7d467aa61cd09520618508.mp4',
#  '/mnt/elice/dataset/test/32d5ad9a24e0460fb77576051dac7c4d.mp4',
#  '/mnt/elice/dataset/test/32e1317781e540038de1a0fbad465bf5.mp4',
#  '/mnt/elice/dataset/test/332fb5c070e24426b480fb603ed484cc.mp4',
#  '/mnt/elice/dataset/test/3336c7c73093455094b3ecb2a742c77c.mp4',
#  '/mnt/elice/dataset/test/33567e6f32c24bd28dd607ee107fb764.mp4',
#  '/mnt/elice/dataset/test/335f6cda4b67425dab25ec00cee8a9ff.mp4',
#  '/mnt/elice/dataset/test/336222a8542c448c9317ebff56332c0b.mp4',
#  '/mnt/elice/dataset/test/3374c0aa05c7419281a31dc6381f8f95.mp4',
#  '/mnt/elice/dataset/test/33d2375277554dc9be856c0be4d60432.mp4',
#  '/mnt/elice/dataset/test/33ef6953b8c94987a4d5f8ee73d969dc.mp4',
#  '/mnt/elice/dataset/test/3418c8c2b27d444f8fd0f081ae50888d.mp4',
#  '/mnt/elice/dataset/test/341ff3c72d1c422cb9065ab9f7f90889.mp4',
#  '/mnt/elice/dataset/test/3420e121b82e4dc7afff62327297c81d.mp4',
#  '/mnt/elice/dataset/test/3426271b90934f10b39beaef2d445331.mp4',
#  '/mnt/elice/dataset/test/3437c98d947e4b10af2834b5d926c2a7.mp4',
#  '/mnt/elice/dataset/test/3439ea4126b948c6a11d76c3be05900f.mp4',
#  '/mnt/elice/dataset/test/348dc9a6e27d4e049c2d3d0b86c25ae4.mp4',
#  '/mnt/elice/dataset/test/349add028a884b9a80e1a390e754e2c1.mp4',
#  '/mnt/elice/dataset/test/34a62bc307324eb1a051ec37e61f456e.mp4',
#  '/mnt/elice/dataset/test/34a739b9bbfc405e809c436baa4c7ba3.mp4',
#  '/mnt/elice/dataset/test/34b1184778bb47ca80f45eb7492a6ece.mp4',
#  '/mnt/elice/dataset/test/34cb6b71c8934c1e843eb12b2b78e884.mp4',
#  '/mnt/elice/dataset/test/34ec8fafef5740abbd1cf2a90a5fcd67.mp4',
#  '/mnt/elice/dataset/test/34fa97c53139469db12568e8fcb45279.mp4',
#  '/mnt/elice/dataset/test/3517c9c9d9664597a71abde95c29f034.mp4',
#  '/mnt/elice/dataset/test/3521364c17e74de8adc13c09c2a3d9ab.mp4',
#  '/mnt/elice/dataset/test/353f5dd5d0c443179f9a46e593c2a928.mp4',
#  '/mnt/elice/dataset/test/3555dd202d0d45aca5cc408bff8bef9c.mp4',
#  '/mnt/elice/dataset/test/35637e2d912042c4bd5fa019330c3bed.mp4',
#  '/mnt/elice/dataset/test/356bc3b249944ce793632d0266621cdf.mp4',
#  '/mnt/elice/dataset/test/3571fb59e7394bd99aaa2f4a1bb637aa.mp4',
#  '/mnt/elice/dataset/test/35749480581845cfa619c821050fa1a5.mp4',
#  '/mnt/elice/dataset/test/35df252a97544ce9874c939297ef022f.mp4',
#  '/mnt/elice/dataset/test/35ec05edbad343a086bd1c1adac014e3.mp4',
#  '/mnt/elice/dataset/test/3630586ddf2843dc818c569e37268240.mp4',
#  '/mnt/elice/dataset/test/3641dadbbbd744b7993694a8f78a3afa.mp4',
#  '/mnt/elice/dataset/test/365356b0233c44cda619b82983f13407.mp4',
#  '/mnt/elice/dataset/test/365e2d7fe62745959e2ea0c54681d2ff.mp4',
#  '/mnt/elice/dataset/test/366a65b603e14e899804f6c7bd1b1ddb.mp4',
#  '/mnt/elice/dataset/test/368f22a052a144c8aa415d5d967c29ec.mp4',
#  '/mnt/elice/dataset/test/36e429d8872f4ac49ac92324eec1fef3.mp4',
#  '/mnt/elice/dataset/test/3718cdb31fef4eed8767e68243dd9f4f.mp4',
#  '/mnt/elice/dataset/test/3739f3fdf60b469787a555b494544874.mp4',
#  '/mnt/elice/dataset/test/375788e0ff144f278724b48e306271f9.mp4',
#  '/mnt/elice/dataset/test/37964c84145c47f69e006ebc3b1feb5b.mp4',
#  '/mnt/elice/dataset/test/37a660d0982c4c18bd366b30a0a2ae3a.mp4',
#  '/mnt/elice/dataset/test/37dca12dc3504a4da281bb82f5d38520.mp4',
#  '/mnt/elice/dataset/test/37eaaf387a9543928e1a26aa6ee6492a.mp4',
#  '/mnt/elice/dataset/test/37eb08248c6f4528a461322bcd99e7d4.mp4',
#  '/mnt/elice/dataset/test/37f5749a7c1e49948b91ac336f9459bd.mp4',
#  '/mnt/elice/dataset/test/37fa15c952c043ef9f381d8b3d5cb56b.mp4',
#  '/mnt/elice/dataset/test/38343120152c4ccebf4a7493206e5d9b.mp4',
#  '/mnt/elice/dataset/test/383998bd29494e6bbeda5fa88c28d93b.mp4',
#  '/mnt/elice/dataset/test/3842c9fa63f04b709817fae873092196.mp4',
#  '/mnt/elice/dataset/test/38774b06522a4adea5da8f8cb5556bf8.mp4',
#  '/mnt/elice/dataset/test/388565768e514524ad9cffbdb491c430.mp4',
#  '/mnt/elice/dataset/test/38a5c3d0c5aa443e902863df4349dc39.mp4',
#  '/mnt/elice/dataset/test/38cc73ad09294965a96dfab68b693918.mp4',
#  '/mnt/elice/dataset/test/38e0dcce4d734c06bef4a87e8cd9d6f5.mp4',
#  '/mnt/elice/dataset/test/38f71e33f4534a268bef7673cf44a9d9.mp4',
#  '/mnt/elice/dataset/test/390a8b16ccf44a869a021d15954ecf1c.mp4',
#  '/mnt/elice/dataset/test/391ce5e456ba4a16adcd59927b2f00a2.mp4',
#  '/mnt/elice/dataset/test/3928d0799b254908bb83bd392bd9c9e2.mp4',
#  '/mnt/elice/dataset/test/393a128d112047adb3189699e20d01bc.mp4',
#  '/mnt/elice/dataset/test/3944bc5ccc1c4442a57b9d7dfeed912a.mp4',
#  '/mnt/elice/dataset/test/3945d9037c45435bbaa563ed8f608b2b.mp4',
#  '/mnt/elice/dataset/test/394bd9d2d4a84cabbb355908eeea487d.mp4',
#  '/mnt/elice/dataset/test/3951dff5d805425eb950b475c8eb21ef.mp4',
#  '/mnt/elice/dataset/test/395adb8b46de4610b77ce36433fa0a35.mp4',
#  '/mnt/elice/dataset/test/396fab1323134a7abb4b2d7a7f3aef33.mp4',
#  '/mnt/elice/dataset/test/397ffa81fba34dda92ea28a9000960e6.mp4',
#  '/mnt/elice/dataset/test/39bcde2fdb234814bd4835ce76aafe33.mp4',
#  '/mnt/elice/dataset/test/39cab3706e4e48a680d3d95534858fe3.mp4',
#  '/mnt/elice/dataset/test/39ec1a36f30e4b749b8c1b3633fba839.mp4',
#  '/mnt/elice/dataset/test/39fa74b351414092a2c67ade0b2e24c0.mp4',
#  '/mnt/elice/dataset/test/3a16f30122374579a11b10503fe2408b.mp4',
#  '/mnt/elice/dataset/test/3a273d4af7ad4abe81334ec081307c8c.mp4',
#  '/mnt/elice/dataset/test/3a30bbfb36f64277a27d2513b6bea59d.mp4',
#  '/mnt/elice/dataset/test/3a3c11fdf3d2411c9af6ace34a21c360.mp4',
#  '/mnt/elice/dataset/test/3a5ca2d9e14f4b8e92d1617e399be8a7.mp4',
#  '/mnt/elice/dataset/test/3a6e765d5c5b41df9afe0e6cdc87e9f4.mp4',
#  '/mnt/elice/dataset/test/3a8a7dcb88ea468a9ad89cc2dade8ae0.mp4',
#  '/mnt/elice/dataset/test/3a9950db02b444d9898a5afedcaaf7e5.mp4',
#  '/mnt/elice/dataset/test/3a9fd7588ac740fd8e33919e91533212.mp4',
#  '/mnt/elice/dataset/test/3aa28653e0154cfe82590e9d94a932fd.mp4',
#  '/mnt/elice/dataset/test/3aa5ea74d7d14650872ac23d93ffad97.mp4',
#  '/mnt/elice/dataset/test/3ac31029efa04681a30ade42f20fae9d.mp4',
#  '/mnt/elice/dataset/test/3ad736b108bf4503b50f39350d8692fb.mp4',
#  '/mnt/elice/dataset/test/3af1ff56a1694600b170f77eeb390626.mp4',
#  '/mnt/elice/dataset/test/3afdaf57a2fa479997acd98e4966a681.mp4',
#  '/mnt/elice/dataset/test/3b1ec4154c9d4ce18b7d98ebe5fe7366.mp4',
#  '/mnt/elice/dataset/test/3b1ee1c401cd45959cd1c1a498b2ed7a.mp4',
#  '/mnt/elice/dataset/test/3b288a71824e49668cd61b5bfae5076a.mp4',
#  '/mnt/elice/dataset/test/3b2da0185ab742e9a8a5deb71c157f1e.mp4',
#  '/mnt/elice/dataset/test/3b4b6b1249924598901efa814e48f3a4.mp4',
#  '/mnt/elice/dataset/test/3b8eeb9051a141ed87d5329441764213.mp4',
#  '/mnt/elice/dataset/test/3ba0b17a84eb414f967e475cf419f0cb.mp4',
#  '/mnt/elice/dataset/test/3ba34448d902426dbfb343df9802d0dc.mp4',
#  '/mnt/elice/dataset/test/3bab251622374193ba8699475db740f4.mp4',
#  '/mnt/elice/dataset/test/3badcb1f79e943b3869bb457a9e81e4c.mp4',
#  '/mnt/elice/dataset/test/3bb7dd210b2049ab9d673c0c0c96fe4c.mp4',
#  '/mnt/elice/dataset/test/3bc2b783d01f464ea373fe53fb337394.mp4',
#  '/mnt/elice/dataset/test/3bc332008a454d6399076b7cf3f868ee.mp4',
#  '/mnt/elice/dataset/test/3bcc08a08f144f8b89884c89d2b9c61a.mp4',
#  '/mnt/elice/dataset/test/3bd16e6f667c473baa48f6427858e3b2.mp4',
#  '/mnt/elice/dataset/test/3bf5aeca55054a69a02b701a9c39881a.mp4',
#  '/mnt/elice/dataset/test/3c0c14edb1d741dc99d804f442c496f6.mp4',
#  '/mnt/elice/dataset/test/3c0cd0ab8c714003a8d1cd8c97ce1caa.mp4',
#  '/mnt/elice/dataset/test/3c0f08f2b84b415b8b5e3a32e9b30fa0.mp4',
#  '/mnt/elice/dataset/test/3c20a108d8a44ba285a8d0dc01827397.mp4',
#  '/mnt/elice/dataset/test/3c339c0f343b4fab89f5705008aa1c4d.mp4',
#  '/mnt/elice/dataset/test/3c4ed72f782c4deba85ef65b7d5e78e4.mp4',
#  '/mnt/elice/dataset/test/3c603cdf1f5b4ae5b4414ce96eda3af0.mp4',
#  '/mnt/elice/dataset/test/3c9c7fc92f504ee6b67522690b6846ef.mp4',
#  '/mnt/elice/dataset/test/3c9def3501634aeeb68c77833cc5c32c.mp4',
#  '/mnt/elice/dataset/test/3cb36feb45594a79bfc444c88a9d8f0e.mp4',
#  '/mnt/elice/dataset/test/3cccfdc7e97449a0bc2248da2d2d3fa1.mp4',
#  '/mnt/elice/dataset/test/3cd3b6b38a80457aa02e2b48eca163d9.mp4',
#  '/mnt/elice/dataset/test/3cecf9123c0a43a2845c1c17756eeb97.mp4',
#  '/mnt/elice/dataset/test/3cef44bb414c4bacba56eedb990b88e2.mp4',
#  '/mnt/elice/dataset/test/3d0262e1ec8e4fcf88642e6e29a8f86e.mp4',
#  '/mnt/elice/dataset/test/3d18171fcbd446129bcecdbcd2ea7e07.mp4',
#  '/mnt/elice/dataset/test/3d43c405ce904482bebc72d1c01eb87e.mp4',
#  '/mnt/elice/dataset/test/3d499bf0d3ac43a78e102921286db2bb.mp4',
#  '/mnt/elice/dataset/test/3d4c66f1f68b49e3a36daba51fe2f084.mp4',
#  '/mnt/elice/dataset/test/3d58445ad9ab499883a2fbf1ca3fe89a.mp4',
#  '/mnt/elice/dataset/test/3d5d03d4a3464c14a63844541bc340d2.mp4',
#  '/mnt/elice/dataset/test/3d7a74a2c0e4442e8ef28c96d9f20ccd.mp4',
#  '/mnt/elice/dataset/test/3d7fa32f24cd4b56bb6c7354f285d946.mp4',
#  '/mnt/elice/dataset/test/3da556afda424b07b989810ba9085d1b.mp4',
#  '/mnt/elice/dataset/test/3db9e3b34c4a42888719eb3e574a3b9f.mp4',
#  '/mnt/elice/dataset/test/3dbbe4177713409987361790c7cbc2cd.mp4',
#  '/mnt/elice/dataset/test/3dcd66ac3dfc4000ac5ec5cee3dfe4f7.mp4',
#  '/mnt/elice/dataset/test/3de02c2102f8446891adda063bc7691f.mp4',
#  '/mnt/elice/dataset/test/3de47fcdc4e44baea6758efc44e6acca.mp4',
#  '/mnt/elice/dataset/test/3de94bd408ef46dca3d034e7a1df518f.mp4',
#  '/mnt/elice/dataset/test/3df91606c4cf4ebdb2c13787548efa27.mp4',
#  '/mnt/elice/dataset/test/3dffe181f6434219a28c5e378c2dfaf4.mp4',
#  '/mnt/elice/dataset/test/3e0113a961af4f50aa8939ec04580051.mp4',
#  '/mnt/elice/dataset/test/3e12c33ed5664d648418638c7d73c2e8.mp4',
#  '/mnt/elice/dataset/test/3e26992d256e421cbeaea5c83c96506f.mp4',
#  '/mnt/elice/dataset/test/3e3ece7b1f034cc1b7e1e0baccad32f9.mp4',
#  '/mnt/elice/dataset/test/3e40db1751f148118732525f09e1e888.mp4',
#  '/mnt/elice/dataset/test/3e478e16f7134a16b70865105e9e5329.mp4',
#  '/mnt/elice/dataset/test/3e4ab2e163954848a451ef3523293df9.mp4',
#  '/mnt/elice/dataset/test/3e7dbdafcf8248bcb336361713fa3a29.mp4',
#  '/mnt/elice/dataset/test/3e9c6806f697491fb6cc4dd94d728421.mp4',
#  '/mnt/elice/dataset/test/3e9e11b272eb4a99b29e5fbc273cb6cf.mp4',
#  '/mnt/elice/dataset/test/3eb14253aec442f8bf4d9cdf9d1588d7.mp4',
#  '/mnt/elice/dataset/test/3eb2f4e763da4b8f9bc958f4b6151c8a.mp4',
#  '/mnt/elice/dataset/test/3ec1cd438c634e92980c5fdbc96d109b.mp4',
#  '/mnt/elice/dataset/test/3ed56893509441a695bd56e13a3273a9.mp4',
#  '/mnt/elice/dataset/test/3f1c7507de4c4b0680dbac093d08a0a0.mp4',
#  '/mnt/elice/dataset/test/3f1ca70047ef495e82180030e2e9460c.mp4',
#  '/mnt/elice/dataset/test/3f1ff9f2d4904ab69ef15cfd0c2603dd.mp4',
#  '/mnt/elice/dataset/test/3f217bc69bb940f6ab72a89df0f352ce.mp4',
#  '/mnt/elice/dataset/test/3f3af554e78d488f8c452561b3ecf12a.mp4',
#  '/mnt/elice/dataset/test/3f3beace5cba4363aa12bb9d1ecc12bf.mp4',
#  '/mnt/elice/dataset/test/3f70982924d84bdd8e1731b0af4ebd40.mp4',
#  '/mnt/elice/dataset/test/3f75f2b81241422f8fea86590ac16af9.mp4',
# ...
#  '/mnt/elice/dataset/test/409f097ac3ab4e84b325fb429cdbc197.mp4',
#  '/mnt/elice/dataset/test/40a5f2aecb6746cbbded212a174b5d13.mp4',
#  '/mnt/elice/dataset/test/40ef619b4eee4914aba52d62330f59a9.mp4',
#  '/mnt/elice/dataset/test/40fecd7adb744760aef9129a7b9463aa.mp4',
#  '/mnt/elice/dataset/test/41276ff966c44f3dba785eff2d8f9371.mp4',
#  '/mnt/elice/dataset/test/4138cbf93dcb4f5eaaaa414e55e5d7a5.mp4',
#  '/mnt/elice/dataset/test/413f8a745813495ebe37eb5fb173a65f.mp4',
#  '/mnt/elice/dataset/test/414027ec61324abd8672740e7c6d489e.mp4',
#  '/mnt/elice/dataset/test/414d28f78acc4d44b1c54891b5fa634d.mp4',
#  '/mnt/elice/dataset/test/4153b0c8a85c4c099eb1209d8e234cff.mp4',
#  '/mnt/elice/dataset/test/416d556de1e24c2ba676ddc8f9713c5e.mp4',
#  '/mnt/elice/dataset/test/4196297d9c20418d96a291fba6db219e.mp4',
#  '/mnt/elice/dataset/test/41a9ecd9bf154334843f4631f5b9837e.mp4',
#  '/mnt/elice/dataset/test/41c2455b77384ec7ba6dbaefc410fd97.mp4',
#  '/mnt/elice/dataset/test/4228876279a44153a3b578da97f19598.mp4',
#  '/mnt/elice/dataset/test/4246f4d743d64e16804bb54eecf60ac1.mp4',
#  '/mnt/elice/dataset/test/42634d15cd5d45c694fc44ed3e1a43b8.mp4',
#  '/mnt/elice/dataset/test/42640b12cba14bfbb551cda9a2d14d52.mp4',
#  '/mnt/elice/dataset/test/42b4b3263d2d41ecbfcf15e35f39084b.mp4',
#  '/mnt/elice/dataset/test/42bade9b74764797b313f1479b8eb3df.mp4',
#  '/mnt/elice/dataset/test/42bb9e80ed664fac8f32bc0305bbeb4b.mp4',
#  '/mnt/elice/dataset/test/42c5ebeb02a144c3868d937aa19f36c3.mp4',
#  '/mnt/elice/dataset/test/42eb21beabc64e31b0065d382e6da098.mp4',
#  '/mnt/elice/dataset/test/432f1c3371274cfeb3ab72e6d95ff4b6.mp4',
#  '/mnt/elice/dataset/test/433feaad86b44f0a80806036585c300f.mp4',
#  '/mnt/elice/dataset/test/438761f4341b4905a0d68764bb5286e3.mp4',
#  '/mnt/elice/dataset/test/438edd8bb7244f3282fe91ee0874f5ab.mp4',
#  '/mnt/elice/dataset/test/439de8e01ed1464caabd185a12197ae0.mp4',
#  '/mnt/elice/dataset/test/43a002f9ebaf4f469556432989cde032.mp4',
#  '/mnt/elice/dataset/test/43a3ac0d580146df8e31ae04ae62c7b3.mp4',
#  '/mnt/elice/dataset/test/43c40b725a6c43b7998c82aaac1ed987.mp4',
#  '/mnt/elice/dataset/test/43cf41e98a7a457d833e70143d77b867.mp4',
#  '/mnt/elice/dataset/test/4424742d64524ec69e163bf4de300169.mp4',
#  '/mnt/elice/dataset/test/4439b4fd66f24afba365a1b9174cea54.mp4',
#  '/mnt/elice/dataset/test/444851c483b3497e94316dd6c9cb18e7.mp4',
#  '/mnt/elice/dataset/test/444f7acb0d4f4f18bb453031a3d0f6c8.mp4',
#  '/mnt/elice/dataset/test/447427e571784325b88fadc26276c0dc.mp4',
#  '/mnt/elice/dataset/test/447644e106fd435392c34b2cd417856b.mp4',
#  '/mnt/elice/dataset/test/4489f20aa8b44ed1a4c690ae978725f7.mp4',
#  '/mnt/elice/dataset/test/448e42cafb2242dca83d71e1f8f3dd42.mp4',
#  '/mnt/elice/dataset/test/44cc3c2734214c4aae9807f43595ebe4.mp4',
#  '/mnt/elice/dataset/test/4504a6038a5e40e99577869572f756d4.mp4',
#  '/mnt/elice/dataset/test/4533a85ff3c540dc8a6c23e847da0f29.mp4',
#  '/mnt/elice/dataset/test/455d2012e5f648cd87e278a9fc999981.mp4',
#  '/mnt/elice/dataset/test/457aa33ae637465e80626655a2d27d1f.mp4',
#  '/mnt/elice/dataset/test/45816a48bc374fbe841f1e416929b775.mp4',
#  '/mnt/elice/dataset/test/45a35b5cd79e4f8eb4a7e4546699213a.mp4',
#  '/mnt/elice/dataset/test/45b9f65ab8f043c6ac83fa371d57517d.mp4',
#  '/mnt/elice/dataset/test/45c319ccdbb6474daf5e31c1c9060816.mp4',
#  '/mnt/elice/dataset/test/45ce7866c201428eb3662ede1ff2ddbf.mp4',
#  '/mnt/elice/dataset/test/45d735def2d64510b2303316c7b57d6b.mp4',
#  '/mnt/elice/dataset/test/462b8d10c7724369a745c46bd1dd7643.mp4',
#  '/mnt/elice/dataset/test/46318176c2b5456b9160a3df0e8baeeb.mp4',
#  '/mnt/elice/dataset/test/4638373816344bbf89975650a6bdd78f.mp4',
#  '/mnt/elice/dataset/test/46444e87cc5445f89401e49f5161531b.mp4',
#  '/mnt/elice/dataset/test/466556900a8643819bfc5694a13b697a.mp4',
#  '/mnt/elice/dataset/test/466a670b25604c7a989d1ad72e0bde83.mp4',
#  '/mnt/elice/dataset/test/469dc0078cff47ac90a98c7e3111bf0c.mp4',
#  '/mnt/elice/dataset/test/46a00d0f78ea4d03875f8f15fc0ca0e8.mp4',
#  '/mnt/elice/dataset/test/46b94abbb31c4d36a778d5daf1284718.mp4',
#  '/mnt/elice/dataset/test/46cfa9f6c69e4f5e88c9f560ac5ecaf9.mp4',
#  '/mnt/elice/dataset/test/47052e33c8a14feaaeb8057287877ddc.mp4',
#  '/mnt/elice/dataset/test/4707070bb23f4ea4a39e68419ecc2d94.mp4',
#  '/mnt/elice/dataset/test/47257e384e4043cf8f1ec7669664d0f7.mp4',
#  '/mnt/elice/dataset/test/476eec29873e434f896f689c012bbba7.mp4',
#  '/mnt/elice/dataset/test/47750e7900484646871928e930572f20.mp4',
#  '/mnt/elice/dataset/test/4776f0b395584108a50c904ec5505f78.mp4',
#  '/mnt/elice/dataset/test/478636b314b542c7a4cb53c3aa5e8b04.mp4',
#  '/mnt/elice/dataset/test/478fccdc885d40ed8bebffdfc955e447.mp4',
#  '/mnt/elice/dataset/test/479ae240e5b84ba69af3ccb4e5a46ad0.mp4',
#  '/mnt/elice/dataset/test/47f555520d594115bef9445af06ee196.mp4',
#  '/mnt/elice/dataset/test/4802935abf744b079d2f7dcc1166ea3b.mp4',
#  '/mnt/elice/dataset/test/482b504535d14e869416388c64b00440.mp4',
#  '/mnt/elice/dataset/test/4875c5ee9395426db49a8bc79c0136e9.mp4',
#  '/mnt/elice/dataset/test/488a19bf749b47209b81cddd6877a66c.mp4',
#  '/mnt/elice/dataset/test/4890452fc62f4e839c509235db2a7d4c.mp4',
#  '/mnt/elice/dataset/test/48906d89114d443f991232e49a03f3a5.mp4',
#  '/mnt/elice/dataset/test/4897d757440d47be9b3c40d6e3e9be6f.mp4',
#  '/mnt/elice/dataset/test/48c85d12fc4946ec989ac372de3b250a.mp4',
#  '/mnt/elice/dataset/test/48f5e712c75342fdbcc2be43c01a73bf.mp4',
#  '/mnt/elice/dataset/test/48fe341eed5749d686dbb5065cffc6e4.mp4',
#  '/mnt/elice/dataset/test/491cb38b5707411cbccd5fe5059c8dde.mp4',
#  '/mnt/elice/dataset/test/4923fd6ebaac4aa1b573d0c216629483.mp4',
#  '/mnt/elice/dataset/test/494706c52d394222aa970f92977f2ba4.mp4',
#  '/mnt/elice/dataset/test/496accb97d184af2b22c2c328d31fac7.mp4',
#  '/mnt/elice/dataset/test/496e08969dc3462e892e59ae5f6efde1.mp4',
#  '/mnt/elice/dataset/test/497f87d22b2244fe82df9f0f77ce07be.mp4',
#  '/mnt/elice/dataset/test/4990472b6d644eac8fbbaf61ffc5d159.mp4',
#  '/mnt/elice/dataset/test/49a0a8d180c449c38aa2bb9c6c720c4c.mp4',
#  '/mnt/elice/dataset/test/49ae734fd1324ef88fe0527da74d6bc1.mp4',
#  '/mnt/elice/dataset/test/49b3abd588b541649175dda61d7ce9ad.mp4',
#  '/mnt/elice/dataset/test/49b4d71f5f264ed1a297aacb828e0f49.mp4',
#  '/mnt/elice/dataset/test/49cbb5a65330497e8681bbca0d54033a.mp4',
#  '/mnt/elice/dataset/test/49d63176428c4276adc687e72bc1eadb.mp4',
#  '/mnt/elice/dataset/test/49eb809900fd47b2851b2bcdc03ebb33.mp4',
#  '/mnt/elice/dataset/test/4a107b10b16c4e45a8ebea8f06afdeec.mp4',
#  '/mnt/elice/dataset/test/4a1e993f306e496d8bfad6d44e319ce4.mp4',
#  '/mnt/elice/dataset/test/4a716e0ed03845bbb1c8724ca8605293.mp4',
#  '/mnt/elice/dataset/test/4a7a6ca5ba2c46958756d81b9dfdd9af.mp4',
#  '/mnt/elice/dataset/test/4a7db6671f7f422c8efbc8b16c99eeee.mp4',
#  '/mnt/elice/dataset/test/4a96a43c415947d58decbc950c2ac6fb.mp4',
#  '/mnt/elice/dataset/test/4aa8ce3be6964bd49c976db05b3af852.mp4',
#  '/mnt/elice/dataset/test/4aae199b0d394b7f8192a63cdc17c65d.mp4',
#  '/mnt/elice/dataset/test/4ad03f82fbc14478bc14b5343738ee7e.mp4',
#  '/mnt/elice/dataset/test/4add0600a61b4045ac8d68a9a260edce.mp4',
#  '/mnt/elice/dataset/test/4aff9be08515439aa22522aa23978eb3.mp4',
#  '/mnt/elice/dataset/test/4b0a1de2916747768d7796d74d0e0fc1.mp4',
#  '/mnt/elice/dataset/test/4b31b3223fe749f58da8e3dc48f95ab4.mp4',
#  '/mnt/elice/dataset/test/4b3593fd43e64fd2af91103a8807c7dc.mp4',
#  '/mnt/elice/dataset/test/4b521ddb4e9c46e08c4166e5acc719ee.mp4',
#  '/mnt/elice/dataset/test/4b6249c1e9e2411fa8eed0b1bf9bbde6.mp4',
#  '/mnt/elice/dataset/test/4b672985badc4ff28096ca74c7edc18a.mp4',
#  '/mnt/elice/dataset/test/4b6897dfef194c119c8631777cab69d9.mp4',
#  '/mnt/elice/dataset/test/4b7b8101158a4acf9ef9960632200359.mp4',
#  '/mnt/elice/dataset/test/4b8fbf5bb5364a5cb5cddb7b8f20baeb.mp4',
#  '/mnt/elice/dataset/test/4bac5d651cfd446abfcfc2fd640ab2ba.mp4',
#  '/mnt/elice/dataset/test/4bb6ef371bd7429da2bc34e3ce7db16b.mp4',
#  '/mnt/elice/dataset/test/4bc62ae4967046caaa6daf85071698ff.mp4',
#  '/mnt/elice/dataset/test/4bcd143514524b378aa4d7e0285d4587.mp4',
#  '/mnt/elice/dataset/test/4bd32a17e598479da7a3f8863bca9c7e.mp4',
#  '/mnt/elice/dataset/test/4bdd8cbf504e4c75aebace803419b384.mp4',
#  '/mnt/elice/dataset/test/4c33a9366b8d4ab69ab8e2b7327dec94.mp4',
#  '/mnt/elice/dataset/test/4c583d01bc954d67b9bc32050fe68c45.mp4',
#  '/mnt/elice/dataset/test/4c7315610b8c4eaa895edfa31ce235a6.mp4',
#  '/mnt/elice/dataset/test/4c9657d2f0a6426f8714d6385b949b5e.mp4',
#  '/mnt/elice/dataset/test/4c98db3f748d4240b0d7ee6d3e37f8d9.mp4',
#  '/mnt/elice/dataset/test/4ca6e9adb6a24df5830fbdcadadf1a77.mp4',
#  '/mnt/elice/dataset/test/4cb97787222849e295cb61c5c23dab17.mp4',
#  '/mnt/elice/dataset/test/4cbf6f6fa4204fc6b8ebd9e967114aec.mp4',
#  '/mnt/elice/dataset/test/4d05532876934a52946aacb1cac76e2d.mp4',
#  '/mnt/elice/dataset/test/4d0a2095883443caa792c6db835fb848.mp4',
#  '/mnt/elice/dataset/test/4d28f9dcbf934d1ca390ddd7bfa3b603.mp4',
#  '/mnt/elice/dataset/test/4d39f6e1b75b4b1b9d6d8cf6bd1dc4fa.mp4',
#  '/mnt/elice/dataset/test/4d3a1e9bb8414a0e80b300ad54fac666.mp4',
#  '/mnt/elice/dataset/test/4d6f1acaa4704d99827885a7f16f4dae.mp4',
#  '/mnt/elice/dataset/test/4d718696a97a430dbaf7705a602047a7.mp4',
#  '/mnt/elice/dataset/test/4d953d7ea6824cb698ce3d46872263f7.mp4',
#  '/mnt/elice/dataset/test/4d9c70a5defa4102927c7c9a0201ec6b.mp4',
#  '/mnt/elice/dataset/test/4dc33d3b2dfc453a97142d3a7b139886.mp4',
#  '/mnt/elice/dataset/test/4dcefffb0bc444b4beff4f4ff0b28799.mp4',
#  '/mnt/elice/dataset/test/4ddedabef56845ab8b90e937da2e2eff.mp4',
#  '/mnt/elice/dataset/test/4ddfd86d39ac482fbf4e61b0cbad70c1.mp4',
#  '/mnt/elice/dataset/test/4dee5a4adb504272bc246470a655fe5a.mp4',
#  '/mnt/elice/dataset/test/4defe793b48447bb82593d189074f626.mp4',
#  '/mnt/elice/dataset/test/4df1562c8e3b412da8cc54a9e5adc513.mp4',
#  '/mnt/elice/dataset/test/4dff069723cb46de88222d5f2d0c390e.mp4',
#  '/mnt/elice/dataset/test/4e0c2b13f4f84f1cbf673a1899b2be0c.mp4',
#  '/mnt/elice/dataset/test/4e51dd3324344c51a2e165e0236eb1f4.mp4',
#  '/mnt/elice/dataset/test/4e60eacde6bf4ea79ee5d01a6a06c75f.mp4',
#  '/mnt/elice/dataset/test/4e60eeb024a5439f96fd9a83042fd3ba.mp4',
#  '/mnt/elice/dataset/test/4e679393102f4c29938b65be92d1177f.mp4',
#  '/mnt/elice/dataset/test/4e7938e8ebd245158b82e04b0d021343.mp4',
#  '/mnt/elice/dataset/test/4e94f9b2989f473b8a4bebb5907d6616.mp4',
#  '/mnt/elice/dataset/test/4ec300476acb4f3a80f7095dfc946b0f.mp4',
#  '/mnt/elice/dataset/test/4ec8f4cb1ea84a118b3ff10cfc355e19.mp4',
#  '/mnt/elice/dataset/test/4ecaa96d615c48dd8aed4a4bd82739f3.mp4',
#  '/mnt/elice/dataset/test/4eddd08a3d67447987ca58c82774f733.mp4',
#  '/mnt/elice/dataset/test/4eee6c5873ff4437b7375f3ac40bb577.mp4',
#  '/mnt/elice/dataset/test/4f067f743d554eeaa4e3d5c4693e0518.mp4',
#  '/mnt/elice/dataset/test/4f3b377328844c4f99c45edb93ceeb5b.mp4',
#  '/mnt/elice/dataset/test/4f70548193224bbab206bd4ede6d6a28.mp4',
#  '/mnt/elice/dataset/test/4f9593c7508940ed904f4557fcbfcbaf.mp4',
#  '/mnt/elice/dataset/test/4fa25a5297d142f9b6d2a8e0e5a76e25.mp4',
#  '/mnt/elice/dataset/test/4fbddf0323a74a8c817eb6566c961cb9.mp4',
#  '/mnt/elice/dataset/test/4fc206da17124809b008756ca4879ec1.mp4',
#  '/mnt/elice/dataset/test/4fc30068ea694601bd9503aa9bc88bf4.mp4',
#  '/mnt/elice/dataset/test/4fe2be1dda22472c9c5486698fc00d3f.mp4',
#  '/mnt/elice/dataset/test/503cb0bcd20b438da369dded2c06b0bc.mp4',
#  '/mnt/elice/dataset/test/506f72b4760d4709b9aab5694ab221c6.mp4',
#  '/mnt/elice/dataset/test/50ec74e57eea4b83b7e5446b75ff988b.mp4',
#  '/mnt/elice/dataset/test/5114b05a515d41179be2e64f3e480bde.mp4',
#  '/mnt/elice/dataset/test/5115c14093214f82912ecd541e6549d3.mp4',
#  '/mnt/elice/dataset/test/511c3c2eb00e4419adcf1588541cfa0e.mp4',
#  '/mnt/elice/dataset/test/513376c4311f441a90e3c3b4c0752a02.mp4',
#  '/mnt/elice/dataset/test/5134658bbba54ce5930b3a96f4c417a5.mp4',
#  '/mnt/elice/dataset/test/513655df156940a3966e5c9c7e68a218.mp4',
#  '/mnt/elice/dataset/test/5142646d15814cbea64c3716bd7cd71b.mp4',
#  '/mnt/elice/dataset/test/5156b1eda78c46a288e998008526403d.mp4',
#  '/mnt/elice/dataset/test/5160d597d4eb489a96bf153b4860cbc8.mp4',
#  '/mnt/elice/dataset/test/5166e1ba7dcc47d48b73e66714d0053e.mp4',
#  '/mnt/elice/dataset/test/517c2d0cb0f84498af47aef9c4c6ea30.mp4',
#  '/mnt/elice/dataset/test/517e110c6a0943e2b42a151dbcf50d5d.mp4',
#  '/mnt/elice/dataset/test/519dab2511f4480fa74bea2ea1ac8ca4.mp4',
#  '/mnt/elice/dataset/test/51c1ba99888f4e4f97e0e3efdd9bacaf.mp4',
#  '/mnt/elice/dataset/test/51c5c69ea2804c248048d7631156e6b6.mp4',
#  '/mnt/elice/dataset/test/51f07637780a4b7a86abb38bdd89c909.mp4',
#  '/mnt/elice/dataset/test/5202d47b60134b018d7158eb1d3e67dc.mp4',
#  '/mnt/elice/dataset/test/521361202cfa46f983a9fb65f955dd7c.mp4',
#  '/mnt/elice/dataset/test/52179240531847bb9b75b2259c9662cb.mp4',
#  '/mnt/elice/dataset/test/521b7b1922a342959bb743e69794a3a2.mp4',
#  '/mnt/elice/dataset/test/5238c930d65443328406558be4eff82f.mp4',
#  '/mnt/elice/dataset/test/5240648068d0497ab29296eb950c7d91.mp4',
#  '/mnt/elice/dataset/test/52653bb5274744e69ff37b6e928dee68.mp4',
#  '/mnt/elice/dataset/test/52a3eb9739b444ed814b1168e98ff6a3.mp4',
#  '/mnt/elice/dataset/test/52b84ecb98d04deca94dcd80dfe68d8f.mp4',
#  '/mnt/elice/dataset/test/52c5a1ef0e4342a99c3640c2c2074007.mp4',
#  '/mnt/elice/dataset/test/52ea6694bea245e392a66182bd1a49e5.mp4',
#  '/mnt/elice/dataset/test/532d216c818e4ec5b0f77df680f659b7.mp4',
#  '/mnt/elice/dataset/test/533cc9f028d045afa24775450af570b8.mp4',
#  '/mnt/elice/dataset/test/5355ce48a5c3474a8eac3bce1ffd2505.mp4',
#  '/mnt/elice/dataset/test/536753e605154fd48fe1a46c83ae8db6.mp4',
#  '/mnt/elice/dataset/test/536d5b6dbb1d44cf97f7b6504842bd7c.mp4',
#  '/mnt/elice/dataset/test/5373cd9d013c459ebebc0f23a4cb2933.mp4',
#  '/mnt/elice/dataset/test/53a4be3e594f4185b9ea56222681b682.mp4',
#  '/mnt/elice/dataset/test/53c010927dec4c46a0776e10e0969da5.mp4',
#  '/mnt/elice/dataset/test/53dde7e1145b47e991255321f6ffff22.mp4',
#  '/mnt/elice/dataset/test/53f444b878fe4c559109a313684500da.mp4',
#  '/mnt/elice/dataset/test/544538d1a89045448afbd428b5180a47.mp4',
#  '/mnt/elice/dataset/test/544a5d86d652483e80df5537ad49a53f.mp4',
#  '/mnt/elice/dataset/test/5456cfa530bb4231a87cd639637e2a79.mp4',
#  '/mnt/elice/dataset/test/546eb4888d4c49fd8bbed1f166a27900.mp4',
#  '/mnt/elice/dataset/test/5478b2b4c3584d94b229dfff3bb83f5e.mp4',
#  '/mnt/elice/dataset/test/5496fa46093d4146966173da0c586e40.mp4',
#  '/mnt/elice/dataset/test/54a57432c00749bbb64a93177afd5c81.mp4',
#  '/mnt/elice/dataset/test/54a6f99b30e64498a9cfdfe8a533b2c4.mp4',
#  '/mnt/elice/dataset/test/54a7fc8da65f43deb5604f8065e0a5d3.mp4',
#  '/mnt/elice/dataset/test/54b57322dea44bbc8e03339ea9682359.mp4',
#  '/mnt/elice/dataset/test/54bc1e132280486c974ae77f7d154b70.mp4',
#  '/mnt/elice/dataset/test/5508720a0ebe4c32b63ddcf12e7a0e38.mp4',
#  '/mnt/elice/dataset/test/551256e2197f48d0959f76ae5e083c72.mp4',
#  '/mnt/elice/dataset/test/5514bb75db4e428490472c2c2275d09d.mp4',
#  '/mnt/elice/dataset/test/55284b8a150e473797d696659b2dfb2b.mp4',
#  '/mnt/elice/dataset/test/553b7206a23f4b248dd52e15b73c976f.mp4',
#  '/mnt/elice/dataset/test/556d93eda62a48029660451dd43749b5.mp4',
#  '/mnt/elice/dataset/test/55b5a6ac664b419b9081383a3bc00b55.mp4',
#  '/mnt/elice/dataset/test/55b970ea55ae44b688c957b996484b93.mp4',
#  '/mnt/elice/dataset/test/55bd2e29e8c7407b858862be1bd0a0cb.mp4',
#  '/mnt/elice/dataset/test/55c5186be4614d0e9e63564b57a7c922.mp4',
#  '/mnt/elice/dataset/test/55f08ba199f2437494a046a13ef6f6ad.mp4',
#  '/mnt/elice/dataset/test/560f6ac221ce4cd59ad106a0032b5fd9.mp4',
#  '/mnt/elice/dataset/test/5619935c1a9449d6942bea84982b68d1.mp4',
#  '/mnt/elice/dataset/test/5620e0cf363d4923819353e538859e9d.mp4',
#  '/mnt/elice/dataset/test/56470602decc4fc4be9b6649e2242f19.mp4',
#  '/mnt/elice/dataset/test/566f79799591455c91655bc81598d9dc.mp4',
#  '/mnt/elice/dataset/test/56784b230c6543a6a1f93f502ed9e3d6.mp4',
#  '/mnt/elice/dataset/test/56833da4120c4950a7519094f1599eca.mp4',
#  '/mnt/elice/dataset/test/5684aca3b81745bb80926b1b74faf118.mp4',
#  '/mnt/elice/dataset/test/5694c5efcf2a43e2abeaa4596d48a248.mp4',
#  '/mnt/elice/dataset/test/56a911e6712b43c58654acb78430fd0e.mp4',
#  '/mnt/elice/dataset/test/56b41ea4586d4b1c8f365067492d0ada.mp4',
#  '/mnt/elice/dataset/test/57068bb6d8b546f09445224c5f9b5fda.mp4',
#  '/mnt/elice/dataset/test/57593308400b4d9bb87508a1679a1d0f.mp4',
#  '/mnt/elice/dataset/test/576aad9f8d7741f29691c74e74fff63b.mp4',
#  '/mnt/elice/dataset/test/5789ac670be04a438ceb3b969f40d613.mp4',
#  '/mnt/elice/dataset/test/57af0b52237d4c9faee761b29f4e391f.mp4',
#  '/mnt/elice/dataset/test/57b9fcbdf2ef47be8c4a183e3a84eaf8.mp4',
#  ...]

# %%
import pandas as pd
submission = pd.read_csv('sample_submission.csv')
submission
# Out:
#                                       path label
# 0     000ee59f529d4d069edee33b887bb2ce.mp4  real
# 1     0018214f560f4ba3871dd9218f55dd48.mp4  real
# 2     00241f732f934e2b807cf493d02ff80b.mp4  fake
# 3     00473872f36940a0bfe3f3dfd7667449.mp4  real
# 4     004d9c5bee68438397889c71a32a05d5.mp4  real
# ...                                    ...   ...
# 2995  ffa0960e6c154c478b6b1781bda78e08.mp4  real
# 2996  ffa34ed0124f459885b99401fc2f706c.mp4  real
# 2997  ffd9e5c5e71a4c33a0b63d3676d15d52.mp4  real
# 2998  ffde5e9809f34b43ae7decca08f37d0c.mp4  fake
# 2999  fff4f11155264d809045f5de16bd2169.mp4  fake
#
# [3000 rows x 2 columns]

# %% [markdown]
# ### 정답 label 기록
#
# 모델이 추론한 label로 submission의 label을 채워넣습니다.

# %%
test_transform = transforms.Compose([
    transforms.ToTensor(),
    transforms.CenterCrop(256),
    transforms.Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225])
])

# %%
# 데이터셋 및 데이터 로더 설정
test_dataset = VideoDataset(directory=test_files, transform=test_transform, mode='test')
total_size = len(test_dataset)

test_loader = DataLoader(test_dataset, batch_size=2, shuffle=False)

print(total_size )
# Out:
# 3000

# %%
model_resnet50 = timm.create_model('res2net50_26w_4s', pretrained=True, num_classes=2).to(device)
model_resnet50.load_state_dict(torch.load('resnet_best_model_0.9726.pt', map_location=device))

model_inc4 = timm.models.inception_v4(pretrained=True,num_classes=2).to(device)
model_inc4.load_state_dict(torch.load('incv4_model_0.974.pt', map_location=device))

model = timm.create_model('xception', pretrained=True, num_classes=2).to(device)
model.load_state_dict(torch.load('xception_best_model_0.974.pt', map_location=device))

model2 = timm.models.resnext50d_32x4d(pretrained=True,num_classes=2).to(device)
model2.load_state_dict(torch.load('resnext_best_model_0.975.pt', map_location=device))

model_renest50d = timm.create_model('resnest50d.in1k', pretrained=True, num_classes=2).to(device)
model_renest50d.load_state_dict(torch.load('resnest_best_model_0.976.pt', map_location=device))

# fft
model_twin = VideoClassifier(num_classes=2).to(device)
model_twin.load_state_dict(torch.load('best_model_twin_0.972.pt', map_location=device))
# Out:
# /home/elicer/.local/lib/python3.10/site-packages/timm/models/_factory.py:117: UserWarning: Mapping deprecated model name xception to current legacy_xception.
#   model = create_fn(
# <All keys matched successfully>

# %%
import torch.fft as fft# 모델을 평가 모드로 설정
model.eval()
model_inc4.eval()
model_resnet50.eval()
model_renest50d.eval()
model2.eval()
model_twin.eval()

# 예측 결과를 저장할 리스트 초기화
predictions = []

# 테스트 데이터셋 순회
with torch.no_grad():
    for data in tqdm(test_loader, desc="Testing"):
        inputs, fft_input = data[0].to(device),data[1].to(device)
        outputs1 = model(inputs)
        outputs2 = model_inc4(inputs)
        outputs3 = model_resnet50(inputs)
        outputs4 = model_renest50d(inputs)
        outputs5 = model2(inputs)
        outputs6 = model_twin(inputs, fft_input)
        
        outputs = (outputs1 + outputs2 + outputs3 + outputs4  + outputs5  + outputs6)/6

        # 예측된 클래스를 가져옵니다 (예: softmax의 최대값)
        _, predicted = torch.max(outputs.data, 1)
        predictions.extend(predicted.cpu().numpy())
# Out:
# Testing: 100%|██████████| 1500/1500 [05:50<00:00,  4.28it/s]

# %%
converted_predictions = ['fake' if pred == 1 else 'real' for pred in predictions]
converted_predictions
# Out:
# ['real',
#  'real',
#  'fake',
#  'real',
#  'real',
#  'real',
#  'real',
#  'fake',
#  'real',
#  'fake',
#  'fake',
#  'real',
#  'fake',
#  'fake',
#  'real',
#  'real',
#  'real',
#  'fake',
#  'fake',
#  'real',
#  'fake',
#  'real',
#  'real',
#  'fake',
#  'fake',
#  'real',
#  'fake',
#  'real',
#  'real',
#  'fake',
#  'real',
#  'real',
#  'fake',
#  'fake',
#  'real',
#  'real',
#  'real',
#  'fake',
#  'fake',
#  'fake',
#  'fake',
#  'real',
#  'real',
#  'fake',
#  'fake',
#  'fake',
#  'real',
#  'fake',
#  'fake',
#  'real',
#  'fake',
#  'real',
#  'real',
#  'real',
#  'real',
#  'fake',
#  'fake',
#  'fake',
#  'fake',
#  'real',
#  'real',
#  'real',
#  'real',
#  'real',
#  'real',
#  'fake',
#  'fake',
#  'real',
#  'real',
#  'fake',
#  'real',
#  'fake',
#  'fake',
#  'real',
#  'fake',
#  'real',
#  'real',
#  'fake',
#  'fake',
#  'fake',
#  'real',
#  'fake',
#  'fake',
#  'fake',
#  'fake',
#  'real',
#  'fake',
#  'fake',
#  'real',
#  'fake',
#  'fake',
#  'real',
#  'real',
#  'fake',
#  'real',
#  'fake',
#  'real',
#  'fake',
#  'fake',
#  'fake',
#  'real',
#  'fake',
#  'fake',
#  'fake',
#  'real',
#  'fake',
#  'fake',
#  'real',
#  'fake',
#  'fake',
#  'real',
#  'fake',
#  'real',
#  'fake',
#  'fake',
#  'real',
#  'fake',
#  'real',
#  'real',
#  'real',
#  'real',
#  'fake',
#  'fake',
#  'fake',
#  'fake',
#  'real',
#  'fake',
#  'fake',
#  'fake',
#  'real',
#  'real',
#  'real',
#  'real',
#  'fake',
#  'fake',
#  'real',
#  'real',
#  'fake',
#  'real',
#  'fake',
#  'real',
#  'fake',
#  'fake',
#  'real',
#  'real',
#  'real',
#  'real',
#  'real',
#  'fake',
#  'real',
#  'real',
#  'fake',
#  'fake',
#  'real',
#  'fake',
#  'fake',
#  'fake',
#  'real',
#  'real',
#  'fake',
#  'real',
#  'real',
#  'real',
#  'real',
#  'real',
#  'fake',
#  'fake',
#  'real',
#  'real',
#  'fake',
#  'fake',
#  'real',
#  'fake',
#  'fake',
#  'fake',
#  'real',
#  'real',
#  'fake',
#  'fake',
#  'real',
#  'fake',
#  'fake',
#  'fake',
#  'real',
#  'real',
#  'real',
#  'fake',
#  'real',
#  'real',
#  'fake',
#  'real',
#  'real',
#  'real',
#  'real',
#  'fake',
#  'real',
#  'fake',
#  'real',
#  'real',
#  'fake',
#  'real',
#  'real',
#  'real',
#  'fake',
#  'fake',
#  'real',
#  'real',
#  'fake',
#  'real',
#  'real',
#  'real',
#  'real',
#  'real',
#  'fake',
#  'real',
#  'fake',
#  'fake',
#  'fake',
#  'fake',
#  'fake',
#  'fake',
#  'fake',
#  'fake',
#  'fake',
#  'fake',
#  'fake',
#  'real',
#  'real',
#  'real',
#  'real',
#  'real',
#  'real',
#  'real',
#  'fake',
#  'fake',
#  'real',
#  'fake',
#  'real',
#  'real',
#  'real',
#  'fake',
#  'real',
#  'real',
#  'real',
#  'real',
#  'real',
#  'real',
#  'fake',
#  'fake',
#  'fake',
#  'fake',
#  'real',
#  'real',
#  'real',
#  'real',
#  'real',
#  'fake',
#  'real',
#  'real',
#  'fake',
#  'fake',
#  'real',
#  'real',
#  'real',
#  'real',
#  'real',
#  'real',
#  'fake',
#  'fake',
#  'real',
#  'real',
#  'real',
#  'fake',
#  'real',
#  'fake',
#  'fake',
#  'fake',
#  'fake',
#  'real',
#  'fake',
#  'real',
#  'fake',
#  'fake',
#  'real',
#  'real',
#  'real',
#  'fake',
#  'real',
#  'real',
#  'real',
#  'fake',
#  'fake',
#  'fake',
#  'real',
#  'fake',
#  'fake',
#  'real',
#  'fake',
#  'real',
#  'fake',
#  'real',
#  'fake',
#  'fake',
#  'real',
#  'real',
#  'fake',
#  'fake',
#  'fake',
#  'real',
#  'real',
#  'real',
#  'fake',
#  'real',
#  'fake',
#  'fake',
#  'real',
#  'real',
#  'fake',
#  'fake',
#  'real',
#  'real',
#  'fake',
#  'real',
#  'real',
#  'real',
#  'fake',
#  'fake',
#  'real',
#  'fake',
#  'fake',
#  'fake',
#  'real',
#  'fake',
#  'fake',
#  'real',
#  'real',
#  'fake',
#  'fake',
#  'real',
#  'real',
#  'real',
#  'real',
#  'fake',
#  'fake',
#  'real',
#  'fake',
#  'real',
#  'fake',
#  'fake',
#  'real',
#  'fake',
#  'fake',
#  'fake',
#  'fake',
#  'real',
#  'fake',
#  'fake',
#  'fake',
#  'real',
#  'fake',
#  'real',
#  'real',
#  'real',
#  'fake',
#  'real',
#  'real',
#  'real',
#  'real',
#  'real',
#  'real',
#  'real',
#  'fake',
#  'fake',
#  'real',
#  'fake',
#  'fake',
#  'fake',
#  'real',
#  'fake',
#  'real',
#  'fake',
#  'fake',
#  'fake',
#  'real',
#  'fake',
#  'fake',
#  'fake',
#  'real',
#  'real',
#  'fake',
#  'real',
#  'fake',
#  'fake',
#  'fake',
#  'fake',
#  'fake',
#  'real',
#  'fake',
#  'fake',
#  'real',
#  'fake',
#  'fake',
#  'fake',
#  'fake',
#  'fake',
#  'fake',
#  'real',
#  'fake',
#  'fake',
#  'real',
#  'real',
#  'real',
#  'fake',
#  'fake',
#  'real',
#  'fake',
#  'fake',
#  'real',
#  'real',
#  'real',
#  'real',
#  'real',
#  'fake',
#  'fake',
#  'real',
#  'fake',
#  'real',
#  'fake',
#  'real',
#  'fake',
#  'fake',
#  'fake',
#  'real',
#  'fake',
#  'fake',
#  'real',
#  'real',
#  'fake',
#  'fake',
#  'real',
#  'real',
#  'real',
#  'fake',
#  'fake',
#  'real',
#  'fake',
#  'fake',
#  'fake',
#  'real',
#  'fake',
#  'real',
#  'real',
#  'fake',
#  'fake',
#  'real',
#  'fake',
#  'fake',
#  'real',
#  'real',
#  'fake',
#  'fake',
#  'real',
#  'fake',
#  'fake',
#  'fake',
#  'fake',
#  'real',
#  'real',
#  'real',
#  'fake',
#  'real',
#  'real',
#  'fake',
#  'real',
#  'real',
#  'real',
#  'fake',
#  'real',
#  'real',
#  'real',
#  'real',
#  'real',
#  'real',
#  'fake',
#  'fake',
#  'fake',
#  'fake',
#  'real',
#  'real',
#  'real',
#  'real',
#  'fake',
#  'fake',
#  'real',
#  'real',
#  'real',
#  'fake',
#  'real',
#  'real',
#  'real',
#  'fake',
#  'fake',
#  'fake',
#  'fake',
#  'real',
#  'real',
#  'real',
#  'real',
#  'real',
#  'fake',
#  'real',
#  'real',
#  'real',
#  'real',
#  'real',
#  'real',
#  'real',
#  'real',
#  'real',
#  'real',
#  'real',
#  'fake',
#  'fake',
#  'fake',
#  'fake',
#  'real',
#  'fake',
#  'real',
#  'real',
#  'fake',
#  'fake',
#  'fake',
#  'real',
#  'real',
#  'real',
#  'real',
#  'fake',
#  'real',
#  'fake',
#  'real',
#  'real',
#  'real',
#  'fake',
#  'real',
#  'real',
#  'real',
#  'real',
#  'real',
#  'real',
#  'fake',
#  'real',
#  'real',
#  'fake',
#  'real',
#  'fake',
#  'real',
#  'fake',
#  'real',
#  'fake',
#  'real',
#  'real',
#  'real',
#  'fake',
#  'fake',
#  'real',
#  'real',
#  'real',
#  'real',
#  'fake',
#  'fake',
#  'fake',
#  'fake',
#  'real',
#  'real',
#  'fake',
#  'fake',
#  'real',
#  'fake',
#  'fake',
#  'fake',
#  'real',
#  'real',
#  'fake',
#  'fake',
#  'fake',
#  'fake',
#  'fake',
#  'real',
#  'real',
#  'fake',
#  'real',
#  'fake',
#  'fake',
#  'real',
#  'fake',
#  'fake',
#  'fake',
#  'real',
#  'real',
#  'fake',
#  'real',
#  'real',
#  'fake',
#  'real',
#  'fake',
#  'real',
#  'fake',
#  'real',
#  'real',
#  'fake',
#  'fake',
#  'fake',
#  'real',
#  'fake',
#  'real',
#  'fake',
#  'real',
#  'real',
#  'fake',
#  'fake',
#  'fake',
#  'real',
#  'fake',
#  'fake',
#  'fake',
#  'fake',
#  'fake',
#  'real',
#  'real',
#  'fake',
#  'fake',
#  'fake',
#  'real',
#  'real',
#  'real',
#  'fake',
#  'real',
#  'fake',
#  'real',
#  'fake',
#  'real',
#  'real',
#  'real',
#  'fake',
#  'real',
#  'fake',
#  'fake',
#  'fake',
#  'real',
#  'fake',
#  'fake',
#  'fake',
#  'real',
#  'real',
#  'real',
#  'real',
#  'fake',
#  'real',
#  'fake',
#  'real',
#  'fake',
#  'fake',
#  'fake',
#  'real',
#  'fake',
#  'fake',
#  'fake',
#  'fake',
#  'real',
#  'real',
#  'real',
#  'fake',
#  'fake',
#  'fake',
#  'real',
#  'real',
#  'fake',
#  'fake',
#  'real',
#  'fake',
#  'fake',
#  'fake',
#  'fake',
#  'real',
#  'real',
#  'real',
#  'real',
#  'fake',
#  'fake',
#  'real',
#  'real',
#  'fake',
#  'fake',
#  'real',
#  'real',
#  'real',
#  'fake',
#  'fake',
#  'real',
#  'real',
#  'fake',
#  'fake',
#  'fake',
#  'fake',
#  'real',
#  'real',
#  'fake',
#  'real',
#  'fake',
#  'real',
#  'real',
#  'fake',
#  'real',
#  'fake',
#  'real',
#  'real',
#  'fake',
#  'fake',
#  'real',
#  'real',
#  'real',
#  'fake',
#  'fake',
#  'real',
#  'real',
#  'fake',
#  'fake',
#  'real',
#  'fake',
#  'real',
#  'real',
#  'fake',
#  'fake',
#  'real',
#  'fake',
#  'real',
#  'real',
#  'real',
#  'real',
#  'fake',
#  'real',
#  'fake',
#  'real',
#  'real',
#  'real',
#  'fake',
#  'fake',
#  'real',
#  'real',
#  'fake',
#  'fake',
#  'fake',
#  'real',
#  'fake',
#  'fake',
#  'real',
#  'real',
#  'real',
#  'real',
#  'fake',
#  'fake',
#  'real',
#  'fake',
#  'fake',
#  'real',
#  'real',
#  'real',
#  'real',
#  'real',
#  'real',
#  'real',
#  'fake',
#  'fake',
#  'real',
#  'fake',
#  'real',
#  'fake',
#  'fake',
#  'fake',
#  'fake',
#  'real',
#  'fake',
#  'fake',
#  'fake',
#  'real',
#  'real',
#  'fake',
#  'real',
#  'fake',
#  'real',
#  'fake',
#  'real',
#  'fake',
#  'real',
#  'real',
#  'fake',
#  'fake',
#  'fake',
#  'fake',
#  'fake',
#  'real',
#  'fake',
#  'real',
#  'real',
#  'fake',
#  'real',
#  'real',
#  'fake',
#  'real',
#  'fake',
#  'fake',
#  'fake',
#  'real',
#  'real',
#  'fake',
#  'real',
#  'fake',
#  'real',
#  'real',
#  'fake',
#  'real',
#  'fake',
#  'fake',
#  'real',
#  'real',
#  'real',
#  'fake',
#  'fake',
#  'fake',
#  'fake',
#  'real',
#  'real',
#  'fake',
#  'real',
#  'fake',
#  'real',
#  'fake',
#  'real',
#  'fake',
#  'real',
#  'real',
#  'fake',
#  'real',
#  'real',
#  'fake',
#  'fake',
#  'real',
#  'real',
#  'fake',
#  'real',
#  'real',
#  'fake',
#  'fake',
#  'fake',
#  'real',
#  'real',
#  'real',
#  'real',
#  'fake',
#  'fake',
#  'fake',
#  'real',
#  'fake',
#  'real',
#  'fake',
#  'real',
#  'real',
#  'fake',
#  'fake',
#  'fake',
#  'real',
#  'real',
#  'real',
#  'real',
#  'fake',
#  'fake',
#  'real',
#  'real',
#  'fake',
#  'fake',
#  'fake',
#  'fake',
#  'fake',
#  'fake',
#  'fake',
#  'fake',
#  'fake',
#  'real',
#  'real',
#  'fake',
#  'real',
#  'real',
#  'real',
#  'fake',
#  'fake',
#  'fake',
#  'real',
#  'fake',
#  'fake',
#  'real',
#  'real',
#  'real',
#  'fake',
#  'real',
#  'fake',
#  'real',
#  'real',
#  'real',
#  'real',
#  'real',
#  'fake',
#  'real',
#  'real',
#  'real',
#  'real',
#  'real',
#  'real',
#  'fake',
#  'real',
#  'real',
#  'fake',
#  'real',
#  'real',
#  'fake',
#  'real',
#  'real',
#  'fake',
#  'fake',
#  'fake',
#  'fake',
#  'real',
#  'real',
#  'real',
#  'fake',
#  'fake',
#  'fake',
#  'fake',
#  'real',
#  'real',
#  'real',
#  'real',
#  'real',
#  'real',
#  'real',
#  'fake',
#  'fake',
#  'real',
#  'fake',
#  'real',
#  'real',
#  'real',
#  'fake',
#  'real',
#  'real',
#  'fake',
#  'fake',
#  'real',
#  'real',
#  'real',
#  'fake',
#  'fake',
#  'real',
#  'fake',
#  'fake',
#  'fake',
#  'real',
#  'real',
#  'real',
#  'fake',
#  'real',
#  'fake',
#  'real',
#  'real',
#  'real',
#  'fake',
#  'real',
#  'real',
#  'real',
#  'fake',
#  'real',
#  'fake',
#  'fake',
#  'real',
#  'fake',
#  'fake',
#  'fake',
#  'fake',
#  'real',
#  'real',
#  'fake',
#  'real',
#  'fake',
#  'real',
#  'real',
#  'real',
#  'real',
#  'real',
#  'real',
#  'real',
#  'real',
#  ...]

# %% [markdown]
# ### 제출파일 생성
#
# 정답을 채워넣은 submission 파일을 제출 파일로 생성합니다.

# %%
submission['label'] = converted_predictions
submission
# Out:
#                                       path label
# 0     000ee59f529d4d069edee33b887bb2ce.mp4  real
# 1     0018214f560f4ba3871dd9218f55dd48.mp4  real
# 2     00241f732f934e2b807cf493d02ff80b.mp4  fake
# 3     00473872f36940a0bfe3f3dfd7667449.mp4  real
# 4     004d9c5bee68438397889c71a32a05d5.mp4  real
# ...                                    ...   ...
# 2995  ffa0960e6c154c478b6b1781bda78e08.mp4  real
# 2996  ffa34ed0124f459885b99401fc2f706c.mp4  real
# 2997  ffd9e5c5e71a4c33a0b63d3676d15d52.mp4  real
# 2998  ffde5e9809f34b43ae7decca08f37d0c.mp4  fake
# 2999  fff4f11155264d809045f5de16bd2169.mp4  fake
#
# [3000 rows x 2 columns]

# %%
submission['label'] = converted_predictions
submission['label'].value_counts()
# Out:
# real    1543
# fake    1457
# Name: label, dtype: int64

# %%
submission.to_csv('sample_submission.csv', index=False)

# %% [markdown]
# ### 제출
#
# 우측 상단의 제출 버튼을 눌러, `code.ipynb` 파일과 `sample_submission.csv` 파일을 제출합니다.
